# %%
import fitz
import base64
import argparse
import json
import re
import io
import os
import subprocess
from tqdm import tqdm
#import ocrmypdf
import requests
import shutil

class PDFParser:
    def __init__(self,path=''):
        if path:
            data = self.get_text(path)
            rating_get_res = self._rating_get(data)
            active_get_res = self._active_get(data)
            subject_get_res = self._subject_get(data)
            no_compes_get_res = self._noCompesation(data)
            get_deferredIssues = self._get_deferredIssues(data)
            get_Decision = self._get_Decision(data)
            self._create_data_for_json(rating_get_res,active_get_res,subject_get_res,no_compes_get_res,get_deferredIssues,get_Decision)
            with open('file.json', 'r') as f:
                d  = json.load(f)
                #pretty-print the JSON data
                print(json.dumps(d, indent=2))


    def process_pdf_files(self):
        # Get the current directory
        current_dir = '/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions'

        # Get a list of PDF files in the current directory
        pdf_files = [file for file in os.listdir(current_dir) if file.endswith(".pdf")]

        # Iterate over each PDF file
        for pdf_file in tqdm(pdf_files[0]):
            # Create a new folder with the PDF file name
            pdf_folder = os.path.splitext(pdf_file)[0]
            os.makedirs(pdf_folder, exist_ok=True)

            # Construct the command to run the script
            command = ["python3", "pdfParser.py", "--argument", pdf_file]

            # Run the script using subprocess
            subprocess.run(command, cwd=current_dir)

            # Move the input PDF and script output to the new folder
            os.rename(pdf_file, os.path.join(pdf_folder, pdf_file))
            os.rename("output.json", os.path.join(pdf_folder, f"{os.path.splitext(pdf_file)[0]}.json"))

# Example usage
# folder_path = "/path/to/SampleRatingDecisions"
# script_path = "/path/to/pdfParser.py"
# process_pdf_files(folder_path, script_path)

    def text_file(self,pdf):
        b64 = self._pdf_to_b64(pdf)
        with open(f'{pdf[:-3]}txt', 'w') as file:
            file.write(b64)

    def get_text(self,pdf):
        text = self._pdf_to_text(pdf)
        return text
    
    def _pdf_to_b64(self,pdf_path):
        with open(pdf_path, "rb") as pdf_file:
            pdf_data = pdf_file.read()

        pdf_b64_string = base64.b64encode(pdf_data).decode("utf-8")

        return pdf_b64_string

    def _pdf_to_text(self,pdf_path):
        if pdf_path.endswith('.txt'):
            with open(pdf_path, 'r') as f:
                b64_string = f.read()
        elif pdf_path.startswith('http'):
            response = requests.get(pdf_path)
            pdf_as_binary_string = response.content
            b64_string = base64.b64encode(pdf_as_binary_string).decode('utf-8')
        else:
            b64_string = self._pdf_to_b64(pdf_path)

        pdf_as_binary_string = base64.b64decode(b64_string)
        binary_stream = io.BytesIO(pdf_as_binary_string)
        datas = []
        pdf_file = fitz.open(stream=binary_stream, filetype='pdf')
        for page_num in range(pdf_file.page_count):
            page = pdf_file[page_num]
            page_text = page.get_text()
            data = page_text.replace('\n', '|')
            if '�' in data:
                data = data.replace("�", " ")
            datas.append(data)

        return datas

    #RATING GET
    def _rating_get(self,data,text=False):
        data = ''.join(data).replace('\n','|')

        lst = data.split('|')

        activeDutydict = {
            'Veterane_name':'None',
            'Va_File_Number':'None',
            'SOCIAL SECURITY NR':'None',
            'POA':'None',
            'CLIENT_CASPIO_FK':'',
            'HEADER_DATE':''
            }
        
        lst  = [i for i in lst if i]
        if 'Rating Decision' not in lst:
            if 'COPY TO' not in  lst[-1] and '/'  in lst[-1]:   
                CLIENT_CASPIO_FK = lst[-2]
                activeDutydict['CLIENT_CASPIO_FK'] = CLIENT_CASPIO_FK
                activeDutydict['HEADER_DATE'] = lst[-1]
            if 'COPY TO' not in  lst[-1] and '/' not in lst[-1]:   
                CLIENT_CASPIO_FK = lst[-1]
                activeDutydict['CLIENT_CASPIO_FK'] = CLIENT_CASPIO_FK
                if '/' in lst[-2]:
                    activeDutydict['HEADER_DATE'] = lst[-2]
 
            



        if 'Rating Decision'  in lst:
            #get CLIENT_CASPIO_FK
            if 'COPY TO' not in  lst[-1] and '/' not in lst[-1]:   
                CLIENT_CASPIO_FK = lst[-1]
                activeDutydict['CLIENT_CASPIO_FK'] = lst[-1]
            if 'COPY TO' not in  lst[-1] and '/'  in lst[-1]:   
                CLIENT_CASPIO_FK = lst[-2]
                activeDutydict['CLIENT_CASPIO_FK'] = CLIENT_CASPIO_FK
                activeDutydict['HEADER_DATE'] = lst[-1]
            #get HEADER DATE
            for i in lst:
                if 'Page' in i :
                    h = lst.index(i)
                    h = lst[h+1]
                    if h[0].isnumeric() and '/' in h:
                        activeDutydict['HEADER_DATE'] = h.strip()
        #remove ccfk 
        lst = [i for i in lst if CLIENT_CASPIO_FK not in i]
        if text== True:
            return lst
        while True:
            try :
                if len(lst) ==0:
                    break
                #VETERANE NAME
                if 'NAME OF VETERAN' in lst[0] and 'VA FILE NUMBER' not in lst[1]:
                    activeDutydict['Veterane_name'] = lst[1].rstrip()
                    if 'VA FILE NUMBER' not in lst[2]:
                        activeDutydict['Veterane_name'] = activeDutydict['Veterane_name']+' '+lst[2].rstrip()
                    del lst[0]
                    continue
                #VA NUMBER
                if 'VA FILE NUMBER' in lst[0] and 'SOCIAL SECURITY NR' not in lst[1]:
                    activeDutydict['Va_File_Number'] = lst[1]
                    del lst[0]
                    continue
                #SOCIAL NUMBER
                if 'SOCIAL SECURITY NR' in lst[0] and 'POA' not in lst[1]:
                    activeDutydict['SOCIAL SECURITY NR'] = lst[1]
                    del lst[0]
                    continue
                #POA
                if 'POA' in lst[0] and 'COPY TO' not in lst[1] and '/' not in lst[1]:
                    activeDutydict['POA'] = lst[1].rstrip()
                    if 'COPY TO' not in lst[2] and '/' not in lst[2] :
                        activeDutydict['POA'] = activeDutydict['POA'] + ' ' + lst[2].rstrip()
                    if 'COPY TO' not in lst[3] and '/' not in lst[3]:
                        activeDutydict['POA'] = activeDutydict['POA'] + ' ' + lst[3].rstrip()
                
                del lst[0]
            except IndexError:
                break

        return activeDutydict  

    #ACTIVE GET
    def _active_get(self,data,text=False):
        data = ''.join(data).replace('\n','|')
        lst = data.split('|')
        activeDutydict = {
            'EOD_Date':'None',
            'RAD_Date':'None',
            'Branch_Service':'None',
            'Discharge_Type':'None',
            }
        info_dics = []
        checker = False
        for row in lst:
            if row.strip() == '':
                del lst[lst.index(row)]
            if 'CHARACTER OF' in row or 'CHARACTEROF' in row:
                lst = lst[lst.index(row):]
                checker = True
        if checker == False:
            return 'None'
        
        pattern_date = r'\d{2}/\d{2}/\d{4}'
        if text == True:
            return lst
        while True:

            if 'LEGACY CODES' in lst[1] or 'LEGACYCODES' in lst[1] :
                break
            
            if  '/' not in lst[1] and ('/'and'LEGACY')  not in lst[2]:
                activeDutydict['EOD_Date'] = ' '
                activeDutydict['RAD_Date'] = ' '
                activeDutydict['Branch_Service'] = lst[1]
                activeDutydict['Discharge_Type'] = lst[2]
                del lst[1]
                del lst[1]
                info_dics.append(activeDutydict.copy())
                activeDutydict['EOD_Date'] = 'None'
                activeDutydict['RAD_Date'] = 'None'
                activeDutydict['Branch_Service']= 'None'
                activeDutydict['Discharge_Type']= 'None'
                continue
            if  len(lst[1].split()) == 1 and '/' in lst[1] and '/' in lst[2] and len(lst[2].split()) == 1:
                activeDutydict['EOD_Date'] = lst[1]
                activeDutydict['RAD_Date'] = lst[2]
                #BRANCH 2x
                if (lst[5][:2].isnumeric() ==False)  and 'LEGACY CODES' not in lst[5]:
                    activeDutydict['Branch_Service'] = lst[3]+' '+lst[4]
                    del lst[4]
                    #BRANCH 3x
                    if (lst[5][:2].isnumeric() ==False)  and 'LEGACY CODES' not in lst[5]:
                        activeDutydict['Branch_Service'] = activeDutydict['Branch_Service']+' '+lst[4]
                        del lst[4]

                #BRANCH 1x
                else:
                    activeDutydict['Branch_Service'] = lst[3]
                
                activeDutydict['Discharge_Type'] = lst[4]
                del lst[1]
                del lst[1]
                del lst[1]
                del lst[1]
                info_dics.append(activeDutydict.copy())
                activeDutydict['EOD_Date'] = 'None'
                activeDutydict['RAD_Date'] = 'None'
                activeDutydict['Branch_Service'] = 'None'
                activeDutydict['Discharge_Type'] = 'None' 
                continue     

            #broken pdfs                                       
            if  len(lst[1].split()) > 1 or len(lst[2].split()) > 1:

                s = lst[1].split()
                
                if  (re.search(pattern_date, lst[2]) and len(lst[2].split()) > 1) and  (re.search(pattern_date, lst[1]) and len(lst[1].split()) == 1):
                    activeDutydict['EOD_Date'] = lst[1].strip()
                    activeDutydict['RAD_Date'] = re.search(pattern_date, lst[2]).group().strip()
                    activeDutydict['Branch_Service']= re.sub(pattern_date, '',lst[2]).strip()
                    activeDutydict['Discharge_Type']=lst[3].strip()
                    del lst[1]
                    del lst[1]
                    del lst[1]

                #if Discharge_Type in lst2 and lens == 3
                if len(s) == 3 and '/' in s[0] and '/' in s[1]:
                    activeDutydict['EOD_Date'] = s[0].strip()
                    activeDutydict['RAD_Date'] = s[1].strip()
                    activeDutydict['Branch_Service']=s[2].strip()
                    activeDutydict['Discharge_Type']=lst[2].strip()
                    del lst[1]
                    del lst[1]

                # all in one row and len brach == 1
                if (len(s) == 4 and  '/' in s[0] and '/' in s[1]) and ('/' in lst[2] or 'LEGACY CODES' in lst[2]):
                    activeDutydict['EOD_Date'] = s[0].strip()
                    activeDutydict['RAD_Date'] = s[1].strip()
                    activeDutydict['Branch_Service']=s[2].strip()
                    activeDutydict['Discharge_Type']=s[3].strip()
                    del lst[1]

                # if Discharge_Type in lst2
                if len(s) == 4 and  '/' in s[0] and '/' in s[1] and '/' not in lst[2]  :
                    activeDutydict['EOD_Date'] = s[0]
                    activeDutydict['RAD_Date'] = s[1]
                    activeDutydict['Branch_Service']=s[2]+' '+s[3]
                    activeDutydict['Discharge_Type']=lst[2]
                    del lst[1]
                    del lst[1]
                # All in one row and len branch == 2
                if len(s) == 5 and  '/' in s[0] and '/' in s[1]:
                    activeDutydict['EOD_Date'] = s[0]
                    activeDutydict['RAD_Date'] = s[1]
                    activeDutydict['Branch_Service']=s[2]+' '+s[3]
                    activeDutydict['Discharge_Type']=s[4]
                    del lst[1]

                info_dics.append(activeDutydict.copy())
                activeDutydict['EOD_Date'] = 'None'
                activeDutydict['RAD_Date'] = 'None'
                activeDutydict['Branch_Service']= 'None'
                activeDutydict['Discharge_Type']= 'None'
                continue

            
            del lst[0]


        return info_dics

    #SUBJECT
    def _subject_get(self,data,text=False):
        
        data = ''.join(data).replace('\n','|')
        SUBJECT_TO = ''
        COMBINED_TO = ''

        for i in data.split('|'):
            if SUBJECT_TO != '' and COMBINED_TO != '':
                break
            if 'SUBJECT TO COMPENSATION' in i or "SUBJECT TO COMPENSATION" in i:
                SUBJECT_TO = i
            if 'COMBINED EVALUATION FOR COMPENSATION' in i or 'COMBINED EVALUATION FOR COMPENSATION' in i:
                COMBINED_TO = i
        if SUBJECT_TO == '' or COMBINED_TO == '':
            return "None"

        SUBJECT_AREA = data.split(f'{SUBJECT_TO}')[1].split(f'{COMBINED_TO}')[0]
        lst = SUBJECT_AREA.split('|')
        lst = [i.strip() for i in lst if i.strip() != '']

        #REMOVE CASPIO
        caspio = self._rating_get(data)['CLIENT_CASPIO_FK']
        if caspio.strip() != '':
            lst = [i for  i in  lst if caspio not in i]
        

        # del rating -> copy to
        new_lst = []
        while True:
            
            if 'Rating Decision' not in lst:
                for i in lst:
                    new_lst.append(i)
                break
            
            if 'Rating Decision' in lst[0] and 'Rating Decision' in lst and 'COPY TO'in lst:
                ind1 = lst.index('Rating Decision')
                ind2 = lst.index('COPY TO')
                del lst[ind1:ind2+1]
                continue
            new_lst.append(lst[0])
            del lst[0]
            continue

        lst = new_lst

        
        #SUBJECT 
        new = '|'.join(lst)
        lst = new.split('|')
        list_of_dict = []
        res = {
            'Code':'',
            'Description':'',
            'PercentageDate':''
        }
        if text == True:
            return lst
        while True:
            if len(lst)==0:
                res['Description'] = res['Description'][:257].lstrip().rstrip()
                res1 = res.copy()
                list_of_dict.append(res1)
                break
            if lst[0].strip()=='':
                del lst[0]
                continue
            
            # next code
            if (lst[0].strip()[:4].isnumeric() and res['Code']!='') and  ('(' not in lst[0] and ')' not in lst[0]):
                description = res['Description']
                res['Description'] = description[:257].strip()
                if 'ASSOCIATED' in description:
                    res['Description'] = description.split('ASSOCIATED')[0].strip()
                elif '[' in description:
                    res['Description'] = description.split('[')[0].strip()

                res1 = res.copy()
                list_of_dict.append(res1)

                code_row = lst[0].strip().split()
                if len(code_row) == 1:
                    res['Code'] = lst[0]
                    res['Description']=''
                    res['PercentageDate']=''
                    del lst[0]
                    continue
                if len(code_row) > 1:
                    res['Code'] = code_row[0]
                    desc = ' '.join(code_row[1:])
                    res['Description'] = desc
                    res['PercentageDate']=''
                    del lst[0]
                    continue
            
            if lst[0].lstrip().split()[0].isnumeric() == True and ("("  in lst[0] or ")"  in lst[0]) :
                if  res['Description'] != '':             
                    res['Description'] = res['Description']+' '+lst[0].strip()
                    del lst[0]
                    continue


            #Code
            # if code & desc in one row
            if lst[0][:4].isnumeric() and len(lst[0].strip().split()) > 1 :
                row_code = lst[0].split()
                if row_code[0][:4].isnumeric():
                    res['Code']= row_code[0]
                    desc = ' '.join(row_code[1:])
                    res['Description'] = desc
                    del lst[0]
                    continue
            if len(lst[0].strip().split()) == 1:
                if lst[0][:4].isnumeric(): #and len(lst[0].strip()) == 4 or lst[0][:4].isnumeric() and len(lst[0].strip()) == 9 :#start
                    res['Code']=lst[0]
                    del lst[0]
                    continue

            #Description
            if lst[0].lstrip().split()[0].isupper() == True and res['Description']=='':
                res['Description'] = lst[0]
                del lst[0]
                continue
            if (lst[0].lstrip().split()[0].isupper()  == True or  ('['or']') in lst[0])  and res['Description']!='' :
                res['Description'] = res['Description']+' '+lst[0].strip()
                del lst[0]
                continue
            if res['Description']!= '' and lst[0].strip()[-1] == ']' and res['Description'].count('[') != res['Description'].count(']'):
                res['Description'] = res['Description']+' '+lst[0].strip()
                del lst[0]
                continue
            


            #First percent
            if 'from' in lst[0] and res['PercentageDate']=='':
                res['PercentageDate'] = lst[0].strip()
                del lst[0]
                continue
            #Second percent
            if 'from' in lst[0] and res['PercentageDate']!='':
                res['PercentageDate'] = res['PercentageDate']+' '+lst[0].lstrip().rstrip()
                del lst[0]
                continue

            if res['Description'].count('[') % 2 !=0 and ']' in lst[0]:
                res['Description'] = res['Description']+' '+lst[0].lstrip().rstrip()
            del lst[0]
            continue
        

        #Percent arraw
        for d in list_of_dict:
            date_lst = []
            date_perc = {'percent':'None','date':'None'}
            row = d['PercentageDate'].split()
            while True:
                if len(row)==0:
                    if date_perc['percent'] !='None':
                        date_lst.append(date_perc.copy())
                        break
                    break
                if date_perc['date'] != 'None' and date_perc['percent'] != 'None':
                    date_lst.append(date_perc.copy())
                    if 'End_Date' in date_perc.keys():
                        del date_perc['End_Date'] 
                    date_perc['date'] = 'None'
                    date_perc['percent'] = 'None'
                    if len(row) == 0:
                        break
                    continue

                if '%' in row[0]:
                    date_perc['percent']=row[0].replace('%','')
                    del row[0]
                    continue
                if row[0].count('/') == 2 and 'to' in row and any('%' in element for element in row) == False:

                    to_ind = row.index('to')
                    date_perc['date'] = row[to_ind-1]
                    date_perc['End_Date'] = row[to_ind+1]
                    del row[0]
                    del row[to_ind]
                    continue

                if  row[0].count('/') == 2:
                    if len(row) > 1:
                        if 'to' in row[1]:
                            date_perc['date'] = row[0]
                            date_perc['End_Date'] = row[2]
                            del row[0]
                            del row[1]
                            continue
                    row[0] = row[0].replace(',','')
                    date_perc['date'] = row[0]
                    del row[0]
                    continue
                del row[0]
            d['PercentageDate']=date_lst
        
        #LEFT OR RIGHT
        for row in list_of_dict:
            desc = row['Description']
            if ('LEFT' in desc and 'RIGHT' in desc) or ('Left' in desc and 'Right' in desc) :
                if desc.index('LEFT') < desc.index('RIGHT'):
                    row['Left_or_Right_KW'] = 'LEFT'
                    continue
                if desc.index('LEFT') > desc.index('RIGHT'):
                    row['Left_or_Right_KW'] = 'RIGHT'
                    continue
            if 'LEFT' in desc or 'Left' in desc:
                row['Left_or_Right_KW'] = 'LEFT'
                continue
            if 'RIGHT' in desc or 'Right' in desc:
                row['Left_or_Right_KW'] = 'RIGHT'
                continue

        return list_of_dict

    #GET EVALUTION
    def _evaluation(self,data):

        data = ''.join(data).replace('\n','|')
        if 'SPECIAL MONTHLY COMPENSATION' not in data:
            evaluation_area = data.split('COMBINED EVALUATION FOR COMPENSATION')[1]
            evaluation_area = ''.join(evaluation_area).split('|NOT SERVICE CONNECTED')[0]
            evaluation_area = ''.join(evaluation_area).split('|')
            evaluation_res = [i.strip() for i in evaluation_area if 'from' in i ]
            return evaluation_res
        if 'SPECIAL MONTHLY COMPENSATION' in data:
            evaluation_area = data.split('COMBINED EVALUATION FOR COMPENSATION')[1]
            evaluation_area = ''.join(evaluation_area).split('|SPECIAL MONTHLY')[0]
            evaluation_area = ''.join(evaluation_area).split('|')
            evaluation_res = [i.strip() for i in evaluation_area if 'from' in i ]
            return evaluation_res

    #GET NO COMPESATION
    def _noCompesation(self,data,text=False):
        list_of_dict = []    
        data = ''.join(data).replace('\n','|')
        lst = data.split('|')
        lst = [i for i in lst if i != ' ' and i != '']
        #start no comp area

        while True:
            try:# if NOT SERVICE CONNECTED not in  data:return None
                if 'NOT SERVICE CONNECTED' in lst[0] or 'NOTSERVICECONNECTED' in lst[0]:
                    del lst[0]
                    break
            except IndexError:
                return list_of_dict
            del lst[0]

        caspio = self._rating_get(data)['CLIENT_CASPIO_FK']

        #REMOVE CASPIO
        if caspio.strip() != '':
            lst = [i.strip() for  i in  lst if caspio not in i and i != ''] 

        new_lst = []
        while True:
            
            if 'Rating Decision' not in lst:
                for i in lst:
                    new_lst.append(i)
                break
            
            if 'Rating Decision' in lst[0] and "COPY TO" in lst:
                    ind2 = lst.index('COPY TO')
                    del lst[:ind2+1]
                    continue
            new_lst.append(lst[0])
            del lst[0]
            continue

        lst = new_lst

        res ={
            'Code':'',
            'Description':''
        }
        if text == True:
            return lst
        while True:

            #STOP ITER
            if len(lst)==0:
                if (res['Code'] and res['Code']) != '':
                    res_copy = res.copy()
                    list_of_dict.append(res_copy)
                break
            #next
            if 'Not Service' in lst[0] or "NotService" in lst[0]:
                description = res['Description']
                res['Description'] = description[:257].strip()
                if 'ASSOCIATED' in description:
                    res['Description'] = description.split('ASSOCIATED')[0].strip()
                    description = res['Description']
                elif '[' in description:
                    res['Description'] = description.split('[')[0].strip()

                res_copy = res.copy()
                list_of_dict.append(res_copy)
                res['Code']=''
                res['Description']=''
                del lst[0]
                continue
            
            # #STOP KEYS
            # if 'ANCILLARY' in lst[0] or 'TREATMENT PURPOSES ONLY' in lst[0] or 'NOT SERVICE CONNECTED' in lst[0] or '____' in lst[0]:
            #     break
            
            strings_to_check = ('DEFERRED ISSUES','TREATMENT PURPOSES ONLY', 'NOT SERVICE CONNECTED', 'DEFERRED ISSUES', '___')

            if any(string in lst[0] for string in strings_to_check):
                break

            #Code
            # if code & desc in one row
            if lst[0][:4].isnumeric() and len(lst[0].strip().split()) > 1 :
                row_code = lst[0].split()
                if row_code[0][:4].isnumeric():
                    res['Code']= row_code[0]
                    desc = ' '.join(row_code[1:])
                    res['Description'] = desc
                    del lst[0]
                    continue
            if len(lst[0].strip().split()) == 1:
                if lst[0][:4].isnumeric(): #and len(lst[0].strip()) == 4 or lst[0][:4].isnumeric() and len(lst[0].strip()) == 9 :#start
                    res['Code']=lst[0]
                    del lst[0]
                    continue

            #DESCRIPTION
            if (lst[0].lstrip().split()[0].isupper() == True and res['Description']== '') and res['Code'] != '':
                res['Description'] = lst[0].rstrip()
                del lst[0]
                continue
            if ((lst[0].lstrip().split()[0].isupper() == True  or  ('[' or ']'or '(' or ')') in lst[0]) and res['Description']!='') and res['Code'] != '':
                res['Description'] = res['Description']+' '+lst[0].strip()
                del lst[0]
                continue



            if res['Description'].count('[') % 2 !=0 and ']' in lst[0]:
                res['Description'] = res['Description']+' '+lst[0].strip()
            del lst[0]
            continue



        #LEFT OR RIGHT
        for row in list_of_dict:
            desc = row['Description']
            if ('LEFT' in desc and 'RIGHT' in desc) or ('Left' in desc and 'Right' in desc) :
                if desc.index('LEFT') < desc.index('RIGHT'):
                    row['Left_or_Right_KW'] = 'LEFT'
                    continue
                if desc.index('LEFT') > desc.index('RIGHT'):
                    row['Left_or_Right_KW'] = 'RIGHT'
                    continue
            if 'LEFT' in desc or 'Left' in desc:
                row['Left_or_Right_KW'] = 'LEFT'
                continue
            if 'RIGHT' in desc or 'Right' in desc:
                row['Left_or_Right_KW'] = 'RIGHT'
                continue

        return list_of_dict
    


        #JSON FILE CREATOR
    
    #DEFERRED Issues
    def _get_deferredIssues(self,data,text=False):
        list_of_dict = []    
        data = ''.join(data).replace('\n','|')
        lst = data.split('|')
        lst = [i for i in lst if i != ' ' and i != '']

        while True:
            try:# if NOT SERVICE CONNECTED not in  data:return None
                if 'DEFERRED ISSUES' in lst[0] or 'DEFERREDISSUES' in lst[0]:
                    del lst[0]
                    break
            except IndexError:
                return list_of_dict
            del lst[0]

        caspio = self._rating_get(data)['CLIENT_CASPIO_FK']

        #REMOVE CASPIO
        if caspio.strip() != '':
            lst = [i.strip() for  i in  lst if caspio not in i and i != ''] 

        new_lst = []
        while True:
            
            if 'Rating Decision' not in lst:
                for i in lst:
                    new_lst.append(i)
                break
            
            if 'Rating Decision' in lst[0] and "COPY TO" in lst:
                    ind2 = lst.index('COPY TO')
                    del lst[:ind2+1]
                    continue
            new_lst.append(lst[0])
            del lst[0]
            continue

        lst = new_lst

        res ={
            'Code':'',
            'Description':''
        }
        if text == True:
            return lst
        while True:

            #STOP ITER
            if len(lst)==0:
                if (res['Code'] and res['Code']) != '':
                    res_copy = res.copy()
                    list_of_dict.append(res_copy)
                break
            #next
            if 'Not Service' in lst[0] or "NotService" in lst[0] or "Static Disability" in lst[0] or "StaticDisability" in lst[0]:
                description = res['Description']
                res['Description'] = description[:257].strip()
                if 'ASSOCIATED' in description:
                    res['Description'] = description.split('ASSOCIATED')[0].strip()
                    description = res['Description']
                elif '[' in description:
                    res['Description'] = description.split('[')[0].strip()
                res_copy = res.copy()
                list_of_dict.append(res_copy)

                res['Code']=''
                res['Description']=''
                del lst[0]
                continue
            
            # #STOP KEYS
            # if 'ANCILLARY' in lst[0] or 'TREATMENT PURPOSES ONLY' in lst[0] or 'NOT SERVICE CONNECTED' in lst[0] or '____' in lst[0]:
            #     break
            
            strings_to_check = ('DEFERRED ISSUES','TREATMENT PURPOSES ONLY', 'NOT SERVICE CONNECTED', 'DEFERRED ISSUES', '___')

            if any(string in lst[0] for string in strings_to_check):
                break

            #Code
            # if code & desc in one row
            if lst[0][:4].isnumeric() and len(lst[0].strip().split()) > 1 :
                row_code = lst[0].split()
                if row_code[0][:4].isnumeric():
                    res['Code']= row_code[0]
                    desc = ' '.join(row_code[1:])
                    res['Description'] = desc
                    del lst[0]
                    continue
            if len(lst[0].strip().split()) == 1:
                if lst[0][:4].isnumeric(): #and len(lst[0].strip()) == 4 or lst[0][:4].isnumeric() and len(lst[0].strip()) == 9 :#start
                    res['Code']=lst[0]
                    del lst[0]
                    continue

            #DESCRIPTION
            if (lst[0].lstrip().split()[0].isupper() == True and res['Description']== '') and res['Code'] != '':
                res['Description'] = lst[0].rstrip()
                del lst[0]
                continue
            if ((lst[0].lstrip().split()[0].isupper() == True  or  ('[' or ']'or '(' or ')') in lst[0]) and res['Description']!='') and res['Code'] != '':
                res['Description'] = res['Description']+' '+lst[0].strip()
                del lst[0]
                continue



            if res['Description'].count('[') % 2 !=0 and ']' in lst[0]:
                res['Description'] = res['Description']+' '+lst[0].strip()
            del lst[0]
            continue

        #LEFT OR RIGHT
        for row in list_of_dict:
            desc = row['Description']
            if ('LEFT' in desc and 'RIGHT' in desc) or ('Left' in desc and 'Right' in desc) :
                if desc.index('LEFT') < desc.index('RIGHT'):
                    row['Left_or_Right_KW'] = 'LEFT'
                    continue
                if desc.index('LEFT') > desc.index('RIGHT'):
                    row['Left_or_Right_KW'] = 'RIGHT'
                    continue
            if 'LEFT' in desc or 'Left' in desc:
                row['Left_or_Right_KW'] = 'LEFT'
                continue
            if 'RIGHT' in desc or 'Right' in desc:
                row['Left_or_Right_KW'] = 'RIGHT'
                continue

        return list_of_dict

    #DECISION
    def _get_Decision(self,data,text=False):
        res ={}
        list_of_dict = []    
        caspioAndDate = self._rating_get(data)
        caspioID = caspioAndDate['CLIENT_CASPIO_FK']
        headerDate  = caspioAndDate['HEADER_DATE']
        data = ''.join(data).replace('|',' ')
        data = re.sub(re.escape(caspioID), '', data)
        data = re.sub(re.escape(headerDate), '', data)
        if "DECISIONS" in data:
            data = data.replace('DECISIONS','')
        data =  data.split('DECISION')[1].split('EVIDENCE')[0]
        pattern = r'(?<=\d\.\s)'

        sentences = re.split(pattern, data)

        data = [sentence.strip() for sentence in sentences if sentence.strip()]
        data = [item for item in data if not item.replace('.','').strip().isdigit()]
        if text == True:
            return data
        for row in data:
            match_name = re.search(r'(?i)(?:(?:evaluation\s*for|Entitlement\s*to\s*an\s*earlier\s*effective\s*date\s*for\s*service\s*connection\s*for|The\s*previous\s*denial\s*of\s*service\s*connection\s*for)|(?:The\s*claim\s*for\s*service\s*connection\s*for)|(?:Evaluation\s*of)|(?:A\s*decision\s*on\s*entitlement\s*to\s*compensation\s*for)|(?:Service\s*connection\s*for))\s+(.+?)\s+(?:is\s*confirmed|as\s*secondary\s*to|remains\s*denied\s*b|which\s*is\s*currently|is\s*granted|is\s*denied|is\s*deferred)', row)
            if match_name:
                decisionName = match_name.group(1)
                if '(' in decisionName:
                    decisionName = decisionName.split('(')[0]
                elif '[' in decisionName:
                    decisionName = decisionName.split('[')[0]
                res['DecisionName'] = decisionName
                
            match_evaluation = re.search(r'(?:A\s*|as\s*secondary\s*to|which\s*is\s*currently|is\s*granted\s*with\s*an\s*evaluation\s*of)\s+(\d+)\s+(?:percent\s*evaluation\s*has\s*been\s*assigned|confirmed\s*and\s*continued|percent\s*disabling|percent\s*effective)', row)
            if match_evaluation:
                res['DecisionEvalution'] = match_evaluation.group(1)

            match_date = re.search(r'\b(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\s+\d{1,2},?\s+\d{4}\b', row)
            if match_date:
                res['EffDate'] = match_date.group()
            
            list_of_dict.append(res.copy())
            res = {}


        return list_of_dict
    
    #JSON
    def _create_data_for_json(self,rating_res,active_res,subject_res,no_compes,deferredIssues,get_Decision):
        js = {
            'Veteran Name':rating_res['Veterane_name'],
            'VA File Number':rating_res['Va_File_Number'],
            'Social Security Number':rating_res['SOCIAL SECURITY NR'],
            'POA':rating_res['POA'],
            'CLIENT_CASPIO_FK':rating_res['CLIENT_CASPIO_FK'],
            'HEADER_DATE':rating_res['HEADER_DATE'],
            'Service Dates':active_res,
            'Compensation':subject_res,   
            'No Compensation':no_compes,
            'Deferred Issues':deferredIssues,
            'Decision':get_Decision
        }
        with open('file.json', 'w') as f:
            json.dump(js, f)


if __name__ == '__main__':
    print("*******************************************")
    print("*                  *                      *")
    print("*      Welcome to the PDF Scraper!        *")
    print("*                  *                      *")
    print("*          Created by Workmovr            *")
    print("*                  *                      *")
    print("*******************************************")

    # parser = argparse.ArgumentParser()
    # parser.add_argument('--argument', required=False)

    # args = parser.parse_args()
    # argument_value = args.argument
    # print(argument_value)
    # parserPDF = PDFParser(argument_value)
    
    
    # path = '/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/McKeown Law -- RatingDecisionExtract Project/Sample RatingDecisions/RatingDecision - 01-17-2023 - 4HPGK2FV.pdf'
    parser  = PDFParser()
    parser.process_pdf_files()

    # parser.text_file(path)




#CHECK WITH EKATERINA
#path = '/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/McKeown Law -- RatingDecisionExtract Project/Sample RatingDecisions/RatingDecision - 02-06-2023 - SOIVWYE8.pdf'
#A difference
#path = '/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/McKeown Law -- RatingDecisionExtract Project/Sample RatingDecisions/RatingDecision - 3-10-2023 - UVN6JWA5.pdf'
# Out:
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|                                                    | 0/41 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 904, in <module>
#     parserPDF = PDFParser(argument_value)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 17, in __init__
#     data = self.get_text(path)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 65, in get_text
#     text = self._pdf_to_text(pdf)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 85, in _pdf_to_text
#     b64_string = self._pdf_to_b64(pdf_path)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 69, in _pdf_to_b64
#     with open(pdf_path, "rb") as pdf_file:
# IsADirectoryError: [Errno 21] Is a directory: 'R'
#   0%|                                                    | 0/41 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# R
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [18], in <cell line: 889>()
#     898 # parser = argparse.ArgumentParser()
#     899 # parser.add_argument('--argument', required=False)
#     900
#    (...)
#     906
#     907 # path = '/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/McKeown Law -- RatingDecisionExtract Project/Sample RatingDecisions/RatingDecision - 01-17-2023 - 4HPGK2FV.pdf'
#     908 parser  = PDFParser()
# --> 909 parser.process_pdf_files()
#
# Input In [18], in PDFParser.process_pdf_files(self)
#      48 subprocess.run(command, cwd=current_dir)
#      50 # Move the input PDF and script output to the new folder
# ---> 51 os.rename(pdf_file, os.path.join(pdf_folder, pdf_file))
#      52 os.rename("output.json", os.path.join(pdf_folder, f"{os.path.splitext(pdf_file)[0]}.json"))
#
# OSError: [Errno 22] Invalid argument: 'R' -> 'R/R'

# %%
import shutil

parser  = PDFParser()
parser.process_pdf_files()
# Out:
#   0%|                                                    | 0/41 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 904, in <module>
#     parserPDF = PDFParser(argument_value)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 17, in __init__
#     data = self.get_text(path)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 65, in get_text
#     text = self._pdf_to_text(pdf)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 85, in _pdf_to_text
#     b64_string = self._pdf_to_b64(pdf_path)
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 69, in _pdf_to_b64
#     with open(pdf_path, "rb") as pdf_file:
# IsADirectoryError: [Errno 21] Is a directory: 'R'
#   0%|                                                    | 0/41 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# R
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 parser  = PDFParser()
# ----> 2 parser.process_pdf_files()
#
# Input In [18], in PDFParser.process_pdf_files(self)
#      48 subprocess.run(command, cwd=current_dir)
#      50 # Move the input PDF and script output to the new folder
# ---> 51 os.rename(pdf_file, os.path.join(pdf_folder, pdf_file))
#      52 os.rename("output.json", os.path.join(pdf_folder, f"{os.path.splitext(pdf_file)[0]}.json"))
#
# OSError: [Errno 22] Invalid argument: 'R' -> 'R/R'

# %%
path = '/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/McKeown Law -- RatingDecisionExtract Project/Sample RatingDecisions/RatingDecision -- 04-13-23 - 4HPGK2FV.pdf'
parser = PDFParser()
data = parser.get_text(path)
rating_get_res = parser._rating_get(data)
active_get_res = parser._active_get(data)
CLIENT_CASPIO_FK = rating_get_res['CLIENT_CASPIO_FK']
subject_get_res = parser._subject_get(data,CLIENT_CASPIO_FK)
no_compes_get_res = parser._noCompesation(data)
get_deferredIssues = parser._get_deferredIssues(data)
get_Decision = parser._get_Decision(data)
parser._create_data_for_json(rating_get_res,active_get_res,subject_get_res,no_compes_get_res,get_deferredIssues,get_Decision)
with open('file.json', 'r') as f:
    d  = json.load(f)
    #pretty-print the JSON data
    print(json.dumps(d, indent=2))
# Out:
# {
#   "Veteran Name": "None",
#   "VA File Number": "None",
#   "Social Security Number": "None",
#   "POA": "None",
#   "CLIENT_CASPIO_FK": "4HPGK2FV",
#   "HEADER_DATE": "04/10/2023",
#   "Service Dates": [
#     {
#       "EOD_Date": "11/18/1987",
#       "RAD_Date": "11/30/2007",
#       "Branch_Service": "Air Force",
#       "Discharge_Type": "Honorable"
#     }
#   ],
#   "Compensation": [
#     {
#       "Code": "9440",
#       "Description": "ADJUSTMENT DISORDER WITH DEPRESSED MOOD",
#       "PercentageDate": [
#         {
#           "percent": "50",
#           "date": "01/14/2020"
#         }
#       ]
#     },
#     {
#       "Code": "5276",
#       "Description": "BILATERAL PLANTAR FASCIITIS",
#       "PercentageDate": [
#         {
#           "percent": "30",
#           "date": "11/03/2020"
#         }
#       ]
#     },
#     {
#       "Code": "5201",
#       "Description": "LEFT SHOULDER TENDINITIS (PREVIOUSLY RATED UNDER DIAGNOSTIC CODE 5201 AND 5201-5019)",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "06/26/2015"
#         },
#         {
#           "percent": "20",
#           "date": "03/03/2017"
#         },
#         {
#           "percent": "20",
#           "date": "03/19/2019"
#         }
#       ],
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "6035-6066",
#       "Description": "KERATOCONUS",
#       "PercentageDate": [
#         {
#           "percent": "30",
#           "date": "12/01/2007"
#         },
#         {
#           "percent": "0",
#           "date": "11/01/2017"
#         },
#         {
#           "percent": "20",
#           "date": "01/25/2021"
#         }
#       ]
#     },
#     {
#       "Code": "5206",
#       "Description": "RIGHT LATERAL EPICONDYLITIS",
#       "PercentageDate": [
#         {
#           "percent": "20",
#           "date": "07/22/2022"
#         }
#       ],
#       "Left_or_Right_KW": "RIGHT"
#     },
#     {
#       "Code": "5024-5201",
#       "Description": "LEFT SHOULDER TENDINITIS",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "12/01/2007",
#           "End_Date": "06/26/2015"
#         },
#         {
#           "percent": "20",
#           "date": "12/29/2022"
#         }
#       ],
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "7899-7806",
#       "Description": "HERPES SIMPLEX TYPE II WITH ACNEFORM DERMATITIS, KERATOSIS PILARIS, AND FOLLICULITIS BARBAE (PREVIOUSLY EVALUATED SEPARATELY)",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "12/01/2007"
#         }
#       ]
#     },
#     {
#       "Code": "7399-7346",
#       "Description": "GASTROESOPHAGEAL REFLUX DISEASE WITH IRRITABLE BOWEL SYNDROME (IBS)",
#       "PercentageDate": [
#         {
#           "percent": "0",
#           "date": "12/01/2007"
#         },
#         {
#           "percent": "10",
#           "date": "07/21/2016"
#         }
#       ]
#     },
#     {
#       "Code": "6260",
#       "Description": "TINNITUS",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "08/03/2020"
#         }
#       ]
#     },
#     {
#       "Code": "6522",
#       "Description": "ALLERGIC RHINITIS",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "01/20/2023"
#         }
#       ]
#     },
#     {
#       "Code": "7101",
#       "Description": "HYPERTENSION",
#       "PercentageDate": [
#         {
#           "percent": "0",
#           "date": "12/01/2007"
#         }
#       ]
#     },
#     {
#       "Code": "7522",
#       "Description": "ERECTILE DYSFUNCTION ASSOCIATED WITH HYPERTENSION",
#       "PercentageDate": [
#         {
#           "percent": "0",
#           "date": "07/22/2022"
#         }
#       ]
#     }
#   ],
#   "No Compensation": [
#     {
#       "Code": "5201",
#       "Description": "RIGHT SHOULDER STRAIN",
#       "Left_or_Right_KW": "RIGHT"
#     },
#     {
#       "Code": "5206",
#       "Description": "LEFT ELBOW CONDITION",
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "5237",
#       "Description": "NECK/UPPER BACK (CERVICAL SPINE)"
#     },
#     {
#       "Code": "5276",
#       "Description": "BILATERAL PES PLANUS"
#     },
#     {
#       "Code": "5299-5206",
#       "Description": "LEFT ELBOW CONDITION",
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "6313",
#       "Description": "VITAMIN D DEFICIENCY"
#     },
#     {
#       "Code": "6512",
#       "Description": "SINUSITIS (PARTICULATE EXPOSURE)"
#     },
#     {
#       "Code": "6847",
#       "Description": "SLEEP APNEA SYNDROMES"
#     },
#     {
#       "Code": "7599-7502",
#       "Description": "KIDNEY DYSFUNCTION (SECONDARY TO HTN)"
#     },
#     {
#       "Code": "7800",
#       "Description": "SURGICAL SCAR ON NECK"
#     },
#     {
#       "Code": "7806",
#       "Description": "ECZEMA"
#     },
#     {
#       "Code": "7820",
#       "Description": "PITYRIASIS ROSEA"
#     },
#     {
#       "Code": "7825",
#       "Description": "URTICARIA"
#     },
#     {
#       "Code": "7903",
#       "Description": "HYPOTHYROIDISM STATUS POST PARTIAL THYROIDECTOMY FOR TREATMENT OF HYPERTHYROIDISM (GRAVE'S DISEASE)"
#     },
#     {
#       "Code": "8100",
#       "Description": "HEADACHES"
#     },
#     {
#       "Code": "8515",
#       "Description": "RIGHT CARPAL TUNNEL SYNDROME",
#       "Left_or_Right_KW": "RIGHT"
#     },
#     {
#       "Code": "8515",
#       "Description": "LEFT CARPAL TUNNEL SYNDROME",
#       "Left_or_Right_KW": "LEFT"
#     }
#   ],
#   "Deferred Issues": [],
#   "Decision": [
#     {
#       "DecisionName": "right lateral epicondylitis ",
#       "DecisionEvalution": "20",
#       "EffDate": "July 22, 2022"
#     },
#     {
#       "DecisionName": "erectile dysfunction",
#       "DecisionEvalution": "0",
#       "EffDate": "July 22, 2022"
#     },
#     {
#       "EffDate": "July 22, 2022"
#     },
#     {
#       "DecisionName": "left elbow condition"
#     }
#   ]
# }

# %%
get_Decision = parser._get_Decision(data,text=True)
get_Decision
# Out:
# ['A 30 percent evaluation has been assigned for bilateral pes planus with plantar fasciitis from April 20, 2022.',
#  'A 20 percent evaluation has been assigned for degenerative arthritis, lumbar spine from April   20, 2022.',
#  'Entitlement to an earlier effective date for service connection for left leg radiculopathy is granted effective April 20, 2022.',
#  'Entitlement to an earlier effective date for service connection for right leg radiculopathy is granted effective April 20, 2022.',
#  'A 20 percent evaluation has been assigned for rotator cuff strain, right shoulder from April 20, 2022.',
#  'A 10 percent evaluation has been assigned for patellofemoral syndrome, left knee from April 20, 2022.',
#  'A 10 percent evaluation has been assigned for patellofemoral syndrome, right knee from April 20, 2022.',
#  'Entitlement to an earlier effective date for service connection for left wrist sprain (claimed as left wrist condition) is granted effective April 20, 2022.',
#  'Entitlement to an earlier effective date for service connection for tinnitus is granted effective April 20, 2022.',
#  'Entitlement to an earlier effective date for service connection for strain, left hip, limitation of abduction is granted effective April 20, 2022.',
#  'Entitlement to an earlier effective date for service connection for strain, left hip, limitation of extension is granted effective April 20, 2022.',
#  'Evaluation of strain, left hip, limitation of flexion, which is currently 10 percent disabling, is continued. 13.',
#  'A difference of opinion has been asserted during the higher-level review for left hand strain (claimed as left hand condition). 14.',
#  'A difference of opinion has been asserted during the higher-level review for right hand strain (claimed as right hand condition).']

# %%
subject_get_res = parser._subject_get(data,text = True)
subject_get_res
# Out:
# ['9440',
#  'ADJUSTMENT DISORDER WITH DEPRESSED MOOD ASSOCIATED WITH LEFT',
#  'SHOULDER TENDINITIS (PREVIOUSLY RATED UNDER DIAGNOSTIC CODE',
#  '5201 AND 5201-5019)',
#  'Service Connected, Gulf War, Secondary',
#  'Static Disability',
#  '50% from 01/14/2020',
#  '5276',
#  'BILATERAL PLANTAR FASCIITIS',
#  'Service Connected, Peacetime, Incurred',
#  'Static Disability',
#  '30% from 11/03/2020',
#  'Original Date of Denial: 06/23/2008',
#  '5201',
#  'LEFT SHOULDER TENDINITIS (PREVIOUSLY RATED UNDER DIAGNOSTIC',
#  'CODE 5201 AND 5201-5019)',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '10% from 06/26/2015 (5201-5019)',
#  '20% from 03/03/2017 (5019-5201)',
#  '20% from 03/19/2019',
#  '6035-6066',
#  'KERATOCONUS',
#  '04/10/2023',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '30% from 12/01/2007 (6035)',
#  '0% from 11/01/2017 (6035)',
#  '20% from 01/25/2021',
#  '5206',
#  'RIGHT LATERAL EPICONDYLITIS',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '20% from 07/22/2022 -Intent To File',
#  '5024-5201',
#  'LEFT SHOULDER TENDINITIS',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '10% from 12/01/2007 to 06/26/2015 (5099-5024)',
#  '20% from 12/29/2022',
#  '7899-7806',
#  'HERPES SIMPLEX TYPE II WITH ACNEFORM DERMATITIS, KERATOSIS',
#  'PILARIS, AND FOLLICULITIS BARBAE (PREVIOUSLY EVALUATED',
#  'SEPARATELY)',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '10% from 12/01/2007',
#  '7399-7346',
#  'GASTROESOPHAGEAL REFLUX DISEASE WITH IRRITABLE BOWEL',
#  'SYNDROME (IBS)',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '0% from 12/01/2007',
#  '10% from 07/21/2016',
#  '6260',
#  'TINNITUS',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '10% from 08/03/2020',
#  '6522',
#  'ALLERGIC RHINITIS [Gulf War Presumptive 3.320/Particulate Matter]',
#  'Service Connected, Gulf War, Presumptive',
#  'Static Disability',
#  '10% from 01/20/2023',
#  '7101',
#  'HYPERTENSION',
#  'Service Connected, Gulf War, Incurred',
#  'Static Disability',
#  '0% from 12/01/2007',
#  '7522',
#  'ERECTILE DYSFUNCTION ASSOCIATED WITH HYPERTENSION',
#  '04/10/2023',
#  'Service Connected, Gulf War, Secondary',
#  'Static Disability',
#  '0% from 07/22/2022 -Intent To File']

# %%
# Get the current directory
current_dir = '/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions'

# Get a list of PDF files in the current directory
pdf_files = [file for file in os.listdir(current_dir) if file.endswith(".pdf")]

# Iterate over each PDF file
pdf_file= pdf_file[0]
# Create a new folder with the PDF file name
pdf_folder = os.path.splitext(pdf_file)[0]
os.makedirs(pdf_folder, exist_ok=True)

# Construct the command to run the script
command = ["python3", "pdfParser.py", "--argument", pdf_file]

# Run the script using subprocess
subprocess.run(command, cwd=current_dir)

# Move the input PDF and script output to the new folder
os.rename(pdf_file, os.path.join(pdf_folder, pdf_file))
os.rename("output.json", os.path.join(pdf_folder, f"{os.path.splitext(pdf_file)[0]}.json"))
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]                   | 0/41 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
#   0%|          | 0/13 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 10, in <module>
#     from tqdm import tqdm
#   File "/opt/anaconda3/lib/python3.9/site-packages/tqdm/__init__.py", line 3, in <module>
#     from .cli import main  # TODO: remove in v5.0.0
#   File "/opt/anaconda3/lib/python3.9/site-packages/tqdm/cli.py", line 7, in <module>
#     from ast import literal_eval as numeric
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 978, in get_code
#   File "<frozen importlib._bootstrap_external>", line 647, in _compile_bytecode
# KeyboardInterrupt
#   0%|          | 0/13 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#   0%|          | 0/13 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#   0%|          | 0/13 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#   0%|          | 0/13 [00:02<?, ?it/s]
#   0%|          | 0/13 [00:11<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#   0%|          | 0/13 [00:13<?, ?it/s]
# Traceback (most recent call last):
#   0%|                                                    | 0/41 [00:14<?, ?it/s]  File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#   0%|          | 0/13 [00:02<?, ?it/s]
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#   0%|          | 0/13 [00:03<?, ?it/s]
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#   0%|          | 0/13 [00:04<?, ?it/s]
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#   0%|          | 0/13 [00:06<?, ?it/s]
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#   0%|          | 0/13 [00:05<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#   0%|          | 0/13 [00:09<?, ?it/s]
#   0%|          | 0/13 [00:11<?, ?it/s]
#   0%|          | 0/13 [00:09<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#   0%|          | 0/13 [00:03<?, ?it/s]
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#   0%|          | 0/13 [00:13<?, ?it/s]
#   0%|          | 0/13 [00:10<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#   0%|          | 0/13 [00:06<?, ?it/s]
# Traceback (most recent call last):
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 909, in <module>
#     parser.process_pdf_files()
#   File "/Users/edgarlalayan/Desktop/CASPIO/Veteran /parser1.5/RatingDecisionExtractProject/SampleRatingDecisions/pdfParser.py", line 48, in process_pdf_files
#     subprocess.run(command, cwd=current_dir)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 507, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1126, in communicate
#     self.wait()
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1189, in wait
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     return self._wait(timeout=timeout)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1917, in _wait
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#     (pid, sts) = self._try_wait(0)
#   File "/opt/anaconda3/lib/python3.9/subprocess.py", line 1875, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
# KeyboardInterrupt
#
# /opt/anaconda3/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 8>()
#      14 command = ["python3", "pdfParser.py", "--argument", pdf_file]
#      16 # Run the script using subprocess
# ---> 17 subprocess.run(command, cwd=current_dir)
#      19 # Move the input PDF and script output to the new folder
#      20 os.rename(pdf_file, os.path.join(pdf_folder, pdf_file))
#
# File /opt/anaconda3/lib/python3.9/subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
# --> 507         stdout, stderr = process.communicate(input, timeout=timeout)
#     508     except TimeoutExpired as exc:
#     509         process.kill()
#
# File /opt/anaconda3/lib/python3.9/subprocess.py:1126, in Popen.communicate(self, input, timeout)
#    1124         stderr = self.stderr.read()
#    1125         self.stderr.close()
# -> 1126     self.wait()
#    1127 else:
#    1128     if timeout is not None:
#
# File /opt/anaconda3/lib/python3.9/subprocess.py:1189, in Popen.wait(self, timeout)
#    1187     endtime = _time() + timeout
#    1188 try:
# -> 1189     return self._wait(timeout=timeout)
#    1190 except KeyboardInterrupt:
#    1191     # https://bugs.python.org/issue25942
#    1192     # The first keyboard interrupt waits briefly for the child to
#    1193     # exit under the common assumption that it also received the ^C
#    1194     # generated SIGINT and will exit rapidly.
#    1195     if timeout is not None:
#
# File /opt/anaconda3/lib/python3.9/subprocess.py:1917, in Popen._wait(self, timeout)
#    1915 if self.returncode is not None:
#    1916     break  # Another thread waited.
# -> 1917 (pid, sts) = self._try_wait(0)
#    1918 # Check the pid and loop as waitpid has been known to
#    1919 # return 0 even without WNOHANG in odd situations.
#    1920 # http://bugs.python.org/issue14396.
#    1921 if pid == self.pid:
#
# File /opt/anaconda3/lib/python3.9/subprocess.py:1875, in Popen._try_wait(self, wait_flags)
#    1873 """All callers to this function MUST hold self._waitpid_lock."""
#    1874 try:
# -> 1875     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1876 except ChildProcessError:
#    1877     # This happens if SIGCLD is set to be ignored or waiting
#    1878     # for child processes has otherwise been disabled for our
#    1879     # process.  This child is dead, we can't get the status.
#    1880     pid = self.pid
#
# KeyboardInterrupt:

# %%
import shutil

pdf_files = [file for file in os.listdir(current_dir) if file.endswith(".pdf")]
for pdf_file in tqdm(pdf_files):
    pdf_folder = pdf_file.split('.')[0]
    os.makedirs(pdf_folder, exist_ok=True)
    command = ["python3", "pdfParser.py", "--argument", pdf_file]
    subprocess.run(command, cwd=current_dir)
    pdf_file_copy_path = os.path.join(pdf_folder, pdf_file)
    shutil.copy(os.path.join(current_dir, pdf_file), pdf_file_copy_path)
    json_file = "file.json"
    json_file_copy_path = os.path.join(pdf_folder, f"{os.path.splitext(pdf_file)[0]}.json")
    shutil.move(os.path.join(current_dir, json_file), json_file_copy_path)
# Out:
#   8%|███▍                                        | 1/13 [00:00<00:05,  2.12it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision -- 04-13-23 - 4HPGK2FV.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "4HPGK2FV",
#     "HEADER_DATE": "04/10/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "11/18/1987",
#           "RAD_Date": "11/30/2007",
#           "Branch_Service": "Air Force",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "9440",
#           "Description": "ADJUSTMENT DISORDER WITH DEPRESSED MOOD",
#           "PercentageDate": [
#             {
#               "percent": "50",
#               "date": "01/14/2020"
#             }
#           ]
#         },
#         {
#           "Code": "5276",
#           "Description": "BILATERAL PLANTAR FASCIITIS",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "11/03/2020"
#             }
#           ]
#         },
#         {
#           "Code": "5201",
#           "Description": "LEFT SHOULDER TENDINITIS (PREVIOUSLY RATED UNDER DIAGNOSTIC CODE 5201 AND 5201-5019)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/26/2015"
#             },
#             {
#               "percent": "20",
#               "date": "03/03/2017"
#             },
#             {
#               "percent": "20",
#               "date": "03/19/2019"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6035-6066",
#           "Description": "KERATOCONUS",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "12/01/2007"
#             },
#             {
#               "percent": "0",
#               "date": "11/01/2017"
#             },
#             {
#               "percent": "20",
#               "date": "01/25/2021"
#             }
#           ]
#         },
#         {
#           "Code": "5206",
#           "Description": "RIGHT LATERAL EPICONDYLITIS",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "07/22/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5024-5201",
#           "Description": "LEFT SHOULDER TENDINITIS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/01/2007",
#               "End_Date": "06/26/2015"
#             },
#             {
#               "percent": "20",
#               "date": "12/29/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "7899-7806",
#           "Description": "HERPES SIMPLEX TYPE II WITH ACNEFORM DERMATITIS, KERATOSIS PILARIS, AND FOLLICULITIS BARBAE (PREVIOUSLY EVALUATED SEPARATELY)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/01/2007"
#             }
#           ]
#         },
#         {
#           "Code": "7399-7346",
#           "Description": "GASTROESOPHAGEAL REFLUX DISEASE WITH IRRITABLE BOWEL SYNDROME (IBS)",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/01/2007"
#             },
#             {
#               "percent": "10",
#               "date": "07/21/2016"
#             }
#           ]
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "08/03/2020"
#             }
#           ]
#         },
#         {
#           "Code": "6522",
#           "Description": "ALLERGIC RHINITIS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "01/20/2023"
#             }
#           ]
#         },
#         {
#           "Code": "7101",
#           "Description": "HYPERTENSION",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/01/2007"
#             }
#           ]
#         },
#         {
#           "Code": "7522",
#           "Description": "ERECTILE DYSFUNCTION ASSOCIATED WITH HYPERTENSION",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "07/22/2022"
#             }
#           ]
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5201",
#           "Description": "RIGHT SHOULDER STRAIN",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5206",
#           "Description": "LEFT ELBOW CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5237",
#           "Description": "NECK/UPPER BACK (CERVICAL SPINE)"
#         },
#         {
#           "Code": "5276",
#           "Description": "BILATERAL PES PLANUS"
#         },
#         {
#           "Code": "5299-5206",
#           "Description": "LEFT ELBOW CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6313",
#           "Description": "VITAMIN D DEFICIENCY"
#         },
#         {
#           "Code": "6512",
#           "Description": "SINUSITIS (PARTICULATE EXPOSURE)"
#         },
#         {
#           "Code": "6847",
#           "Description": "SLEEP APNEA SYNDROMES"
#         },
#         {
#           "Code": "7599-7502",
#           "Description": "KIDNEY DYSFUNCTION (SECONDARY TO HTN)"
#         },
#         {
#           "Code": "7800",
#           "Description": "SURGICAL SCAR ON NECK"
#         },
#         {
#           "Code": "7806",
#           "Description": "ECZEMA"
#         },
#         {
#           "Code": "7820",
#           "Description": "PITYRIASIS ROSEA"
#         },
#         {
#           "Code": "7825",
#           "Description": "URTICARIA"
#         },
#         {
#           "Code": "7903",
#           "Description": "HYPOTHYROIDISM STATUS POST PARTIAL THYROIDECTOMY FOR TREATMENT OF HYPERTHYROIDISM (GRAVE'S DISEASE)"
#         },
#         {
#           "Code": "8100",
#           "Description": "HEADACHES"
#         },
#         {
#           "Code": "8515",
#           "Description": "RIGHT CARPAL TUNNEL SYNDROME",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8515",
#           "Description": "LEFT CARPAL TUNNEL SYNDROME",
#           "Left_or_Right_KW": "LEFT"
#         }
#       ]
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "right lateral epicondylitis ",
#         "DecisionEvalution": "20",
#         "EffDate": "July 22, 2022"
#       },
#       {
#         "DecisionName": "erectile dysfunction",
#         "DecisionEvalution": "0",
#         "EffDate": "July 22, 2022"
#       },
#       {
#         "EffDate": "July 22, 2022"
#       },
#       {
#         "DecisionName": "left elbow condition"
#       }
#     ]
#   }
# }
#  15%|██████▊                                     | 2/13 [00:01<00:05,  1.97it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 5-26-2022 - UVN6JWA5.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "UVN6JWA5",
#     "HEADER_DATE": "",
#     "Service Information": {
#       "Service Dates": "None"
#     },
#     "Compensation Information": {
#       "Compensation": "None",
#       "No Compensation": []
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "left hip trochanteric pain syndrome and femoral acetabular impingement syndrome ",
#         "DecisionEvalution": "40",
#         "EffDate": "March 21, 2020"
#       },
#       {
#         "EffDate": "June 30, 2021"
#       }
#     ]
#   }
# }
#  23%|██████████▏                                 | 3/13 [00:01<00:04,  2.12it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 08-30-2022 - MLIETL9E.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "MLIETL9E",
#     "HEADER_DATE": "08/26/2022",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "11/17/1997",
#           "RAD_Date": "12/02/2006",
#           "Branch_Service": "Marine Corps",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "9413",
#           "Description": "OTHER SPECIFIED TRAUMA AND STRESSOR RELATED DISORDER",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "03/17/2014"
#             },
#             {
#               "percent": "30",
#               "date": "01/05/2022"
#             }
#           ]
#         },
#         {
#           "Code": "5299-5237",
#           "Description": "LOW BACK STRAIN",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/03/2006"
#             }
#           ]
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/03/2006"
#             }
#           ]
#         },
#         {
#           "Code": "7804",
#           "Description": "RIGHT SHOULDER CYST REMOVAL RESIDUALS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/03/2006"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "7802",
#           "Description": "STATUS POST RIGHT THUMB LACERATION WITH RESIDUALS",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "01/05/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5260-5261",
#           "Description": "LEFT KNEE INJURY RESIDUALS",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6100",
#           "Description": "BILATERAL HEARING LOSS"
#         },
#         {
#           "Code": "6201",
#           "Description": "RESIDUALS OF EAR INFECTION"
#         },
#         {
#           "Code": "6599-6511",
#           "Description": "SINUSITIS"
#         },
#         {
#           "Code": "7820",
#           "Description": "LEFT LEG INSECT BITE RESIDUALS",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8100",
#           "Description": "HEADACHES"
#         },
#         {
#           "Code": "8850-5025",
#           "Description": "FIBROMYALGIA"
#         },
#         {
#           "Code": "8866-6602",
#           "Description": "UPPER RESPIRATORY CONDITION/TROUBLE BREATHING"
#         },
#         {
#           "Code": "8885-8515",
#           "Description": "PERIPHERAL NEUROPATHY, RIGHT HAND AND ARM",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "9411",
#           "Description": "POST TRAUMATIC STRESS DISORDER"
#         },
#         {
#           "Code": "9499-9435",
#           "Description": "SLEEP DISORDER"
#         }
#       ]
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "other specified trauma and stressor related disorder,",
#         "DecisionEvalution": "10",
#         "EffDate": "January 5, 2022"
#       },
#       {
#         "DecisionName": "status post right thumb laceration with residuals",
#         "DecisionEvalution": "0",
#         "EffDate": "January 5, 2022"
#       },
#       {
#         "DecisionName": "left shoulder condition"
#       },
#       {
#         "DecisionName": "neck condition secondary back condition"
#       },
#       {
#         "DecisionName": "right knee condition"
#       },
#       {
#         "DecisionName": "right leg radiculopathy secondary to back"
#       },
#       {
#         "DecisionName": "left leg radiculopathy secondary to back"
#       },
#       {
#         "DecisionName": "rhinitis"
#       },
#       {
#         "DecisionName": "low back strain"
#       },
#       {
#         "DecisionName": "right shoulder cyst removal residuals"
#       }
#     ]
#   }
# }
#  31%|█████████████▌                              | 4/13 [00:02<00:04,  1.91it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 01-27-2023 - 0SKEN06Y.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "0SKEN06Y",
#     "HEADER_DATE": "01/26/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "12/27/1978",
#           "RAD_Date": "12/31/1998",
#           "Branch_Service": "Navy",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "6006-6065",
#           "Description": "RIGHT EYE SCOTOMA AND CENTRAL SEROUS RETINOPATHY",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "10/29/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5237",
#           "Description": "LUMBAR SPINE COMPRESSION FRACTURE T12",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "10/29/2021"
#             }
#           ]
#         },
#         {
#           "Code": "5260",
#           "Description": "LEFT KNEE ARTHROSCOPY WITH PARTIAL MEDIAL MENISCECTOMY WITH RESIDUAL PAIN AND DECREASED ROM",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "10/29/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "10/29/2021"
#             }
#           ]
#         },
#         {
#           "Code": "6100",
#           "Description": "BILATERAL HEARING LOSS",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "10/29/2021"
#             }
#           ]
#         },
#         {
#           "Code": "7802",
#           "Description": "RESIDUAL SCAR FOLLOWING LEFT KNEE ARTHROSCOPY ASSOCIATED WITH LEFT KNEE ARTHROSCOPY WITH PARTIAL MEDIAL MENISCECTOMY WITH RESIDUAL PAIN AND DECREASED ROM",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "10/29/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5201",
#           "Description": "LEFT SHOULDER IMPINGEMENT SYNDROME",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5201",
#           "Description": "RIGHT SHOULDER IMPINGEMENT SYNDROME",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5215",
#           "Description": "RIGHT WRIST CONDITION",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5215",
#           "Description": "LEFT WRIST CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5237",
#           "Description": "CERVICAL STRAIN"
#         },
#         {
#           "Code": "6522",
#           "Description": "RHINITIS"
#         },
#         {
#           "Code": "6847",
#           "Description": "SLEEP APNEA"
#         },
#         {
#           "Code": "9435",
#           "Description": "DEPRESSION"
#         }
#       ]
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "rhinitis"
#       },
#       {
#         "DecisionName": "sleep apnea"
#       }
#     ]
#   }
# }
#  38%|████████████████▉                           | 5/13 [00:02<00:04,  1.73it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 1-31-2023 - UVN6JWA5.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "UVN6JWA5",
#     "HEADER_DATE": "01/27/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "09/19/2002",
#           "RAD_Date": "09/18/2004",
#           "Branch_Service": "Army",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "9411",
#           "Description": "POST-TRAUMATIC STRESS DISORDER WITH ALCOHOL USE DISORDER",
#           "PercentageDate": [
#             {
#               "percent": "50",
#               "date": "06/30/2021"
#             }
#           ]
#         },
#         {
#           "Code": "5237",
#           "Description": "LUMBOSACRAL STRAIN",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "06/30/2021"
#             }
#           ]
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/14/2021"
#             }
#           ]
#         },
#         {
#           "Code": "5215",
#           "Description": "RIGHT WRIST STRAIN (MAJOR)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5215",
#           "Description": "LEFT WRIST STRAIN (MINOR)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8516",
#           "Description": "CUBITAL TUNNEL SYNDROME, LEFT UPPER (MINOR)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8516",
#           "Description": "CUBITAL TUNNEL SYNDROME, RIGHT UPPER (MAJOR) ASSOCIATED WITH NECK CONDITION",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5213",
#           "Description": "RIGHT ELBOW CONDITION",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5213",
#           "Description": "LEFT ELBOW CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5237",
#           "Description": "NECK CONDITION"
#         },
#         {
#           "Code": "6100",
#           "Description": "BILATERAL HEARING LOSS"
#         },
#         {
#           "Code": "8865-6511",
#           "Description": "SINUSITIS"
#         },
#         {
#           "Code": "8865-6522",
#           "Description": "RHINITIS"
#         },
#         {
#           "Code": "8873-7319",
#           "Description": "IBS"
#         },
#         {
#           "Code": "8881-8100",
#           "Description": "TENSION HEADACHES"
#         }
#       ]
#     },
#     "Deferred Issues": [
#       {
#         "Code": "8599-8520",
#         "Description": "RIGHT LEG RADICULOPATHY",
#         "Left_or_Right_KW": "RIGHT"
#       },
#       {
#         "Code": "8599-8520",
#         "Description": "LEFT LEG RADICULOPATHY",
#         "Left_or_Right_KW": "LEFT"
#       }
#     ],
#     "Decision": [
#       {
#         "DecisionName": "lumbosacral strain ",
#         "DecisionEvalution": "20",
#         "EffDate": "June 30, 2021"
#       },
#       {
#         "DecisionName": "cubital tunnel syndrome, left upper ",
#         "DecisionEvalution": "10",
#         "EffDate": "June 30, 2021"
#       },
#       {
#         "DecisionName": "cubital tunnel syndrome, right upper ",
#         "DecisionEvalution": "10",
#         "EffDate": "June 30, 2021"
#       },
#       {
#         "DecisionName": "left wrist strain ",
#         "DecisionEvalution": "10",
#         "EffDate": "June 30, 2021"
#       },
#       {
#         "DecisionName": "right wrist strain ",
#         "DecisionEvalution": "10",
#         "EffDate": "June 30, 2021"
#       },
#       {
#         "DecisionName": "left elbow condition"
#       },
#       {
#         "DecisionName": "right elbow condition"
#       },
#       {
#         "DecisionName": "neck condition"
#       },
#       {
#         "DecisionName": "left leg radiculopathy"
#       },
#       {
#         "DecisionName": "right leg radiculopathy"
#       }
#     ]
#   }
# }
#  46%|████████████████████▎                       | 6/13 [00:03<00:04,  1.61it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 12-05-2022 - QSNPLAX1.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "MLIETL9E",
#     "HEADER_DATE": "12/05/2022",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "11/23/2005",
#           "RAD_Date": "01/12/2009",
#           "Branch_Service": "Army",
#           "Discharge_Type": "Honorable"
#         },
#         {
#           "EOD_Date": "11/18/2009",
#           "RAD_Date": "12/26/2010",
#           "Branch_Service": "Army",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "9411",
#           "Description": "POSTTRAUMATIC STRESS DISORDER",
#           "PercentageDate": [
#             {
#               "percent": "50",
#               "date": "07/23/2019"
#             }
#           ]
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/27/2010"
#             }
#           ]
#         },
#         {
#           "Code": "7599-7522",
#           "Description": "ERECTILE DYSFUNCTION ASSOCIATED WITH POSTTRAUMATIC STRESS DISORDER",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "02/11/2021"
#             }
#           ]
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5201",
#           "Description": "RIGHT SHOULDER CONDITION",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5201",
#           "Description": "LEFT SHOULDER CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5237",
#           "Description": "NECK CONDITION"
#         },
#         {
#           "Code": "5271",
#           "Description": "RIGHT ANKLE CONDITION",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5271",
#           "Description": "LEFT ANKLE CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5299-5237",
#           "Description": "LOW BACK CONDITION"
#         },
#         {
#           "Code": "6099-6009",
#           "Description": "A CHRONIC CONDITION TO ACCOUNT FOR PHOTOPHOBIA"
#         },
#         {
#           "Code": "6099-6011",
#           "Description": "BILATERAL EYE CONDITION"
#         },
#         {
#           "Code": "6100",
#           "Description": "HEARING LOSS"
#         },
#         {
#           "Code": "6299-6204",
#           "Description": "A CHRONIC CONDITION TO ACCOUNT FOR DIZZINESS"
#         },
#         {
#           "Code": "6513",
#           "Description": "SINUSITIS"
#         },
#         {
#           "Code": "6522",
#           "Description": "ALLERGIC RHINITIS"
#         },
#         {
#           "Code": "8045",
#           "Description": "RESIDUALS OF A TRAUMATIC BRAIN INJURY"
#         },
#         {
#           "Code": "8099-8045",
#           "Description": "A CHRONIC CONDITION TO ACCOUNT FOR SHORT-TERM MEMORY LOSS"
#         },
#         {
#           "Code": "8199-8100",
#           "Description": "HEADACHES"
#         },
#         {
#           "Code": "8511",
#           "Description": "RIGHT ARM NEUROPATHY",
#           "Left_or_Right_KW": "RIGHT"
#         }
#       ]
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "right arm neuropathy"
#       }
#     ]
#   }
# }
#  54%|███████████████████████▋                    | 7/13 [00:03<00:03,  1.68it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 02-06-2023 - SOIVWYE8.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "SOIVWYE8",
#     "HEADER_DATE": "2/03/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "01/10/1983",
#           "RAD_Date": "06/30/2004",
#           "Branch_Service": "Marine Corps",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "6847",
#           "Description": "SLEEP APNEA",
#           "PercentageDate": [
#             {
#               "percent": "50",
#               "date": "02/20/2009"
#             }
#           ]
#         },
#         {
#           "Code": "5201",
#           "Description": "DEGENERATIVE JOINT DISEASE, RIGHT SHOULDER (NOW CLAIMED AS RIGHT ROTATOR CUFF AND ARM CONDITION)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "02/20/2009"
#             },
#             {
#               "percent": "20",
#               "date": "08/08/2016"
#             },
#             {
#               "percent": "30",
#               "date": "09/22/2020"
#             },
#             {
#               "percent": "30",
#               "date": "02/07/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5213",
#           "Description": "RIGHT ELBOW DEGENERATIVE ARTHRITIS ARTHRITIS WITH TENDINITIS WITH IMPAIRMENT OF SUPINATION AND PRONATION",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "7319",
#           "Description": "IRRITABLE BOWEL SYNDROME",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "04/14/2022"
#             }
#           ]
#         },
#         {
#           "Code": "9435",
#           "Description": "MOOD DISORDER DUE TO KNOWN PHYSIOLOGICAL CONDITION WITH DEPRESSIVE FEATURES.",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "04/14/2022"
#             }
#           ]
#         },
#         {
#           "Code": "5206",
#           "Description": "RIGHT ELBOW DEGENERATIVE ARTHRITIS WITH TENDINITIS AND LIMITATION OF FLEXION",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "02/20/2009"
#             }
#           ]
#         },
#         {
#           "Code": "5003-5215",
#           "Description": "LEFT WRIST DEGENERATIVE ARTHRITIS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5003-5229",
#           "Description": "RIGHT HAND (THUMB, INDEX, LONG FINGERS) DEGENERATIVE ARTHRITIS, OTHER THAN POST TRAUMATIC",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5215-5003",
#           "Description": "RIGHT WRIST DEGENERATIVE ARTHRITIS, OTHER THAN POST-TRAUMATIC",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "7101",
#           "Description": "HYPERTENSION",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "09/22/2020"
#             }
#           ]
#         },
#         {
#           "Code": "5003-5230",
#           "Description": "RIGHT RING FINGER DEGENERATIVE ARTHRITIS 4TH DIP JOINTS",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5003-5230",
#           "Description": "RIGHT LITTLE FINGER DEGENERATIVE ARTHRITIS S/P 5TH METACARPAL FRACTURE",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5207",
#           "Description": "RIGHT ELBOW DEGENERATIVE ARTHRITIS WITH TENDINITIS AND LIMITATION OF EXTENSION",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "04/14/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "7522",
#           "Description": "ERECTILE DYSFUNCTION ASSOCIATED WITH HYPERTENSION",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "04/14/2022"
#             }
#           ]
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5003-5271",
#           "Description": "DEGENERATIVE JOINT DISEASE LEFT ANKLE",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5237",
#           "Description": "DEGENERATIVE JOINT DISEASE, CERVICAL SPINE, DORSAL KYPHOSIS, THORACIC SPINE AND DEGENERATIVE JOINT DISEASE, SACROILIAC JOINTS (NOW CLAIMED AS SACROILITIS, ANKYLOSING SPONDYLITIS, AND NECK CONDITION)"
#         },
#         {
#           "Code": "5252",
#           "Description": "BILATERAL HIP STRAIN (CLAIMED AS ARTHRITIS, BILATERAL HIPS)"
#         },
#         {
#           "Code": "5260",
#           "Description": "DEGENERATIVE JOINT DISEASE, RIGHT AND LEFT KNEE",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5271",
#           "Description": "ANKYLOSING SPONDYLITIS IN THE RIGHT ANKLE",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "6100",
#           "Description": "BILATERAL HEARING LOSS"
#         },
#         {
#           "Code": "6399-7806",
#           "Description": "ANAPHYLAXIS, CLAIMED AS ANAPHYLACTIC SHOCK, TREATMENTS FOR BEE STINGS"
#         },
#         {
#           "Code": "7720",
#           "Description": "ANEMIA"
#         },
#         {
#           "Code": "8100",
#           "Description": "MIGRAINE HEADACHES"
#         }
#       ]
#     },
#     "Deferred Issues": [
#       {
#         "Code": "6512",
#         "Description": "SINUSITIS"
#       },
#       {
#         "Code": "6522",
#         "Description": "RHINITIS"
#       },
#       {
#         "Code": "7535",
#         "Description": "KIDNEY DYSFUNCTION"
#       }
#     ],
#     "Decision": [
#       {
#         "DecisionName": "Mood disorder due to known physiological condition with depressive features.",
#         "DecisionEvalution": "30",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "irritable bowel syndrome",
#         "DecisionEvalution": "30",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "right elbow degenerative arthritis with tendinitis with impairment of supination and pronation",
#         "DecisionEvalution": "30",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "right elbow degenerative arthritis with tendinitis and limitation of   flexion",
#         "DecisionEvalution": "20",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "left wrist degenerative arthritis",
#         "DecisionEvalution": "10",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "right hand ",
#         "DecisionEvalution": "10",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "right wrist degenerative arthritis, other than post-traumatic",
#         "DecisionEvalution": "10",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "right elbow degenerative arthritis with tendinitis and limitation of extension",
#         "DecisionEvalution": "0",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "right little finger degenerative arthritis s/p 5th metacarpal fracture ",
#         "DecisionEvalution": "0",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "right ring finger degenerative arthritis 4th DIP joints ",
#         "DecisionEvalution": "0",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "erectile dysfunction",
#         "DecisionEvalution": "0",
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "EffDate": "April 14, 2022"
#       },
#       {
#         "DecisionName": "sinusitis"
#       },
#       {
#         "DecisionName": "rhinitis"
#       },
#       {
#         "DecisionName": "kidney dysfunction"
#       }
#     ]
#   }
# }
#  62%|███████████████████████████                 | 8/13 [00:04<00:02,  1.75it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 01-17-2023 - 4HPGK2FV.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "4HPGK2FV",
#     "HEADER_DATE": "01/12/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "11/26/1990",
#           "RAD_Date": "03/25/1995",
#           "Branch_Service": "Marine Corps",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "5024-5260",
#           "Description": "PATELLOFEMORAL PAIN SYNDROME WITH TENDINOPATHY AND OSGOOD SLATTER'S SYNDROME, RIGHT KNEE",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5024-5260",
#           "Description": "PATELLOFEMORAL PAIN SYNDROME WITH TENDINOPATHY AND OSGOOD SLATTER'S SYNDROME, LEFT KNEE",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2022"
#             }
#           ]
#         },
#         {
#           "Code": "6513",
#           "Description": "SINUSITIS [Environmental Hazard in Gulf War/Other Unidentified]",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "08/10/2022"
#             }
#           ]
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "6100",
#           "Description": "HEARING LOSS"
#         }
#       ]
#     },
#     "Deferred Issues": [
#       {
#         "Code": "7319",
#         "Description": "IRRITABLE BOWEL SYNDROME"
#       },
#       {
#         "Code": "9434",
#         "Description": "DEPRESSION"
#       }
#     ],
#     "Decision": [
#       {
#         "DecisionName": "patellofemoral pain syndrome with tendinopathy and Osgood Slatter's syndrome, right knee",
#         "DecisionEvalution": "10",
#         "EffDate": "June 30, 2022"
#       },
#       {
#         "DecisionName": "patellofemoral pain syndrome with tendinopathy and Osgood Slatter's syndrome, left knee",
#         "DecisionEvalution": "10",
#         "EffDate": "June 30, 2022"
#       },
#       {
#         "DecisionName": "tinnitus",
#         "DecisionEvalution": "10",
#         "EffDate": "June 30, 2022"
#       },
#       {
#         "DecisionName": "sinusitis",
#         "DecisionEvalution": "0",
#         "EffDate": "August 10,   2022"
#       },
#       {},
#       {
#         "DecisionName": "depression"
#       },
#       {
#         "DecisionName": "irritable bowel syndrome"
#       }
#     ]
#   }
# }
#  69%|██████████████████████████████▍             | 9/13 [00:04<00:02,  1.90it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 2-17-2023 - SOIVWYE8.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "SOIVWYE8",
#     "HEADER_DATE": "02/15/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "09/19/2002",
#           "RAD_Date": "09/18/2004",
#           "Branch_Service": "Army",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "9411",
#           "Description": "POST-TRAUMATIC STRESS DISORDER WITH ALCOHOL USE DISORDER",
#           "PercentageDate": [
#             {
#               "percent": "50",
#               "date": "06/30/2021"
#             }
#           ]
#         },
#         {
#           "Code": "5237",
#           "Description": "LUMBOSACRAL STRAIN",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "06/30/2021"
#             }
#           ]
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/14/2021"
#             }
#           ]
#         },
#         {
#           "Code": "5215",
#           "Description": "RIGHT WRIST STRAIN (MAJOR)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5215",
#           "Description": "LEFT WRIST STRAIN (MINOR)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8516",
#           "Description": "CUBITAL TUNNEL SYNDROME, LEFT UPPER (MINOR)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8516",
#           "Description": "CUBITAL TUNNEL SYNDROME, RIGHT UPPER (MAJOR) ASSOCIATED WITH NECK CONDITION",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "06/30/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5213",
#           "Description": "RIGHT ELBOW CONDITION",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5213",
#           "Description": "LEFT ELBOW CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5237",
#           "Description": "NECK CONDITION"
#         },
#         {
#           "Code": "6100",
#           "Description": "BILATERAL HEARING LOSS"
#         },
#         {
#           "Code": "8520",
#           "Description": "RIGHT LEG RADICULOPATHY",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8520",
#           "Description": "LEFT LEG RADICULOPATHY",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8865-6511",
#           "Description": "SINUSITIS"
#         },
#         {
#           "Code": "8865-6522",
#           "Description": "RHINITIS"
#         },
#         {
#           "Code": "8873-7319",
#           "Description": "IBS"
#         },
#         {
#           "Code": "8881-8100",
#           "Description": "TENSION HEADACHES"
#         }
#       ]
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "left leg radiculopathy"
#       },
#       {
#         "DecisionName": "right leg radiculopathy"
#       }
#     ]
#   }
# }
#  77%|█████████████████████████████████          | 10/13 [00:05<00:01,  1.91it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 3-10-2023 - UVN6JWA5.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "UVN6JWA5",
#     "HEADER_DATE": "03/08/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "07/27/1998",
#           "RAD_Date": "12/01/2011",
#           "Branch_Service": "Marine Corps",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "5269-5276",
#           "Description": "BILATERAL PES PLANUS WITH PLANTAR FASCIITIS",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/02/2011"
#             },
#             {
#               "percent": "30",
#               "date": "04/20/2022"
#             }
#           ]
#         },
#         {
#           "Code": "5201",
#           "Description": "ROTATOR CUFF STRAIN, RIGHT SHOULDER",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/02/2011"
#             },
#             {
#               "percent": "20",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5242",
#           "Description": "DEGENERATIVE ARTHRITIS, LUMBAR SPINE",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/02/2011"
#             },
#             {
#               "percent": "20",
#               "date": "04/20/2022"
#             }
#           ]
#         },
#         {
#           "Code": "8520",
#           "Description": "LEFT LEG RADICULOPATHY",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8520",
#           "Description": "RIGHT LEG RADICULOPATHY",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5201-5024",
#           "Description": "ROTATOR CUFF STRAIN, LEFT SHOULDER",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/02/2011"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5215-5024",
#           "Description": "STRAIN, RIGHT WRIST",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/02/2011"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5215",
#           "Description": "LEFT WRIST SPRAIN (CLAIMED AS LEFT WRIST CONDITION)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5252",
#           "Description": "STRAIN, LEFT HIP, LIMITATION OF FLEXION",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/02/2011"
#             },
#             {
#               "percent": "10",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5260",
#           "Description": "PATELLOFEMORAL SYNDROME, RIGHT KNEE",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/02/2011"
#             },
#             {
#               "percent": "10",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5260",
#           "Description": "PATELLOFEMORAL SYNDROME, LEFT KNEE",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/02/2011"
#             },
#             {
#               "percent": "10",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "04/20/2022"
#             }
#           ]
#         },
#         {
#           "Code": "5229",
#           "Description": "RIGHT HAND STRAIN (CLAIMED AS RIGHT HAND CONDITION)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "09/28/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5229",
#           "Description": "LEFT HAND STRAIN (CLAIMED AS LEFT HAND CONDITION)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "09/28/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5251",
#           "Description": "STRAIN, LEFT HIP, LIMITATION OF EXTENSION",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "04/20/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5253",
#           "Description": "STRAIN, LEFT HIP, LIMITATION OF ABDUCTION",
#           "PercentageDate": [
#             {
# ...
#             {
#               "percent": "10",
#               "date": "02/01/2006"
#             },
#             {
#               "percent": "20",
#               "date": "12/13/2021"
#             }
#           ]
#         },
#         {
#           "Code": "8520",
#           "Description": "LEFT LEG RADICULOPATHY WITH SENSORY DEFICIT",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "02/01/2006"
#             },
#             {
#               "percent": "20",
#               "date": "12/13/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "02/01/2006"
#             }
#           ]
#         },
#         {
#           "Code": "5260",
#           "Description": "RIGHT KNEE STRAIN",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/13/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5260",
#           "Description": "LEFT KNEE STRAIN",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/13/2021"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5299-5227",
#           "Description": "STATUS POST RIGHT 5TH FINGER FRACTURE",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "02/01/2006"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "7399-7346",
#           "Description": "MILD GASTROESOPHAGEAL REFLUX DISEASE",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "02/01/2006"
#             }
#           ]
#         },
#         {
#           "Code": "7802",
#           "Description": "SURGICAL SCARS (POSTERIOR TRUNK)",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "02/01/2006"
#             }
#           ]
#         },
#         {
#           "Code": "7806",
#           "Description": "ECZEMA, BILATERAL HANDS",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "02/01/2006"
#             }
#           ]
#         },
#         {
#           "Code": "7800",
#           "Description": "SURGICAL SCARS (NECK)",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/13/2021"
#             }
#           ]
#         },
#         {
#           "Code": "7802",
#           "Description": "SURGICAL SCARS (RIGHT HIP)",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/13/2021"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8865-6522",
#           "Description": "NON ALLERGIC RHINITIS [Gulf War Presumptive 3.320/Particulate Matter] [Environmental Hazard in Gulf War/Undiagnosed Illness]",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "12/13/2021"
#             }
#           ]
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5201",
#           "Description": "LEFT SHOULDER CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6100",
#           "Description": "BILATERAL HEARING LOSS"
#         },
#         {
#           "Code": "6204",
#           "Description": "VERTIGO"
#         },
#         {
#           "Code": "7319",
#           "Description": "IRRITABLE BOWEL SYNDROME"
#         },
#         {
#           "Code": "8045",
#           "Description": "TRAUMATIC BRAIN INJURY (TBI)"
#         },
#         {
#           "Code": "8511",
#           "Description": "RIGHT ARM RADICULOPATHY",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8520",
#           "Description": "RIGHT LEG RADICULOPATHY",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8865-6513",
#           "Description": "SINUSITIS"
#         },
#         {
#           "Code": "9434",
#           "Description": "ACQUIRED PSYCHIATRIC CONDITION (TO INCLUDE DEPRESSION)"
#         }
#       ]
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "left knee strain,",
#         "DecisionEvalution": "10"
#       },
#       {
#         "DecisionName": "right knee strain",
#         "DecisionEvalution": "10",
#         "EffDate": "December 13, 2021"
#       },
#       {
#         "DecisionName": "non allergic rhinitis,",
#         "DecisionEvalution": "0"
#       },
#       {
#         "DecisionName": "sinusitis"
#       },
#       {
#         "DecisionName": "traumatic brain injury "
#       },
#       {
#         "DecisionName": "vertigo"
#       },
#       {
#         "DecisionName": "acquired psychiatric condition "
#       }
#     ]
#   }
# }
#  92%|███████████████████████████████████████▋   | 12/13 [00:06<00:00,  1.95it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 01-18-2023 - N41YE3UE.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "N41YE3UE",
#     "HEADER_DATE": "01/17/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "11/17/1997",
#           "RAD_Date": "12/02/2006",
#           "Branch_Service": "Marine Corps",
#           "Discharge_Type": "Honorable"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "9413",
#           "Description": "OTHER SPECIFIED TRAUMA AND STRESSOR RELATED DISORDER",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "03/17/2014"
#             },
#             {
#               "percent": "30",
#               "date": "01/05/2022"
#             }
#           ]
#         },
#         {
#           "Code": "5237",
#           "Description": "LUMBOSACRAL STRAIN (PREVIOUSLY RATED AS LOW BACK STRAIN)",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/03/2006"
#             }
#           ]
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/03/2006"
#             }
#           ]
#         },
#         {
#           "Code": "7804",
#           "Description": "RIGHT SHOULDER CYST REMOVAL RESIDUALS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "12/03/2006"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "6522",
#           "Description": "ALLERGIC RHINITIS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "08/10/2022"
#             }
#           ]
#         },
#         {
#           "Code": "7802",
#           "Description": "STATUS POST RIGHT THUMB LACERATION WITH RESIDUALS",
#           "PercentageDate": [
#             {
#               "percent": "0",
#               "date": "01/05/2022"
#             }
#           ],
#           "Left_or_Right_KW": "RIGHT"
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "5237",
#           "Description": "NECK CONDITION SECONDARY BACK CONDITION"
#         },
#         {
#           "Code": "5260",
#           "Description": "LEFT SHOULDER CONDITION",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5260",
#           "Description": "RIGHT KNEE CONDITION",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "5260-5261",
#           "Description": "LEFT KNEE INJURY RESIDUALS",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6100",
#           "Description": "BILATERAL HEARING LOSS"
#         },
#         {
#           "Code": "6201",
#           "Description": "RESIDUALS OF EAR INFECTION"
#         },
#         {
#           "Code": "6599-6511",
#           "Description": "SINUSITIS"
#         },
#         {
#           "Code": "7820",
#           "Description": "LEFT LEG INSECT BITE RESIDUALS",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8100",
#           "Description": "HEADACHES"
#         },
#         {
#           "Code": "8520",
#           "Description": "RIGHT LEG RADICULOPATHY SECONDARY TO BACK",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8520",
#           "Description": "LEFT LEG RADICULOPATHY SECONDARY TO BACK",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8850-5025",
#           "Description": "FIBROMYALGIA"
#         },
#         {
#           "Code": "8866-6602",
#           "Description": "UPPER RESPIRATORY CONDITION/TROUBLE BREATHING"
#         },
#         {
#           "Code": "8885-8515",
#           "Description": "PERIPHERAL NEUROPATHY, RIGHT HAND AND ARM",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "9411",
#           "Description": "POST TRAUMATIC STRESS DISORDER"
#         },
#         {
#           "Code": "9499-9435",
#           "Description": "SLEEP DISORDER"
#         }
#       ]
#     },
#     "Deferred Issues": [],
#     "Decision": [
#       {
#         "DecisionName": "allergic rhinitis",
#         "DecisionEvalution": "10",
#         "EffDate": "August 10, 2022"
#       },
#       {
#         "DecisionName": "lumbosacral strain ",
#         "DecisionEvalution": "10"
#       },
#       {
#         "DecisionName": "right shoulder cyst removal residuals,",
#         "DecisionEvalution": "10"
#       },
#       {
#         "DecisionName": "left leg radiculopathy secondary to back"
#       },
#       {
#         "DecisionName": "neck condition secondary back condition"
#       },
#       {
#         "DecisionName": "right leg radiculopathy secondary to back"
#       },
#       {
#         "DecisionName": "left shoulder condition"
#       },
#       {
#         "DecisionName": "right knee condition"
#       }
#     ]
#   }
# }
# 100%|███████████████████████████████████████████| 13/13 [00:06<00:00,  1.90it/s]
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision - 05-01-2023 - 7KWGRH7B.pdf
# {
#   "Veteran": {
#     "Name": "None",
#     "VA File Number": "None",
#     "Social Security Number": "None",
#     "POA": "None",
#     "CLIENT_CASPIO_FK": "7KWGRH7B",
#     "HEADER_DATE": "05/02/2023",
#     "Service Information": {
#       "Service Dates": [
#         {
#           "EOD_Date": "03/06/1974",
#           "RAD_Date": "04/15/1974",
#           "Branch_Service": "Army",
#           "Discharge_Type": "Honorable"
#         },
#         {
#           "EOD_Date": "04/26/1974",
#           "RAD_Date": "02/07/1976",
#           "Branch_Service": "Navy",
#           "Discharge_Type": "Honorable"
#         },
#         {
#           "EOD_Date": "09/10/1976",
#           "RAD_Date": "08/23/1977",
#           "Branch_Service": "Navy",
#           "Discharge_Type": "Under Honorable Conditions"
#         }
#       ]
#     },
#     "Compensation Information": {
#       "Compensation": [
#         {
#           "Code": "5237",
#           "Description": "LUMBOSACRAL STRAIN",
#           "PercentageDate": [
#             {
#               "percent": "40",
#               "date": "11/29/2022"
#             }
#           ]
#         },
#         {
#           "Code": "5237",
#           "Description": "CERVICAL STRAIN",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "11/29/2022"
#             }
#           ]
#         },
#         {
#           "Code": "8100",
#           "Description": "HEADACHES",
#           "PercentageDate": [
#             {
#               "percent": "30",
#               "date": "11/29/2022"
#             }
#           ]
#         },
#         {
#           "Code": "5206",
#           "Description": "LEFT FOREARM LIMITED FLEXION",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "11/29/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "5213",
#           "Description": "LEFT FOREARM LIMITED ROTATION",
#           "PercentageDate": [
#             {
#               "percent": "20",
#               "date": "11/29/2022"
#             }
#           ],
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "6260",
#           "Description": "TINNITUS",
#           "PercentageDate": [
#             {
#               "percent": "10",
#               "date": "11/29/2022"
#             }
#           ]
#         }
#       ],
#       "No Compensation": [
#         {
#           "Code": "6204",
#           "Description": "VERTIGO"
#         },
#         {
#           "Code": "7913",
#           "Description": "IRRITABLE BOWEL SYNDROME"
#         },
#         {
#           "Code": "8599-8510",
#           "Description": "LEFT ARM RADICULOPATHY",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "8599-8510",
#           "Description": "RIGHT ARM RADICULOPATHY",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8599-8520",
#           "Description": "RIGHT LEG RADICULOPATHY",
#           "Left_or_Right_KW": "RIGHT"
#         },
#         {
#           "Code": "8599-8520",
#           "Description": "LEFT LEG RADICULOPATHY",
#           "Left_or_Right_KW": "LEFT"
#         },
#         {
#           "Code": "9411",
#           "Description": "POSTTRAUMATIC STRESS DISORDER"
#         },
#         {
#           "Code": "9440",
#           "Description": "ADJUSTMENT DISORDER WITH ANXIETY"
#         }
#       ]
#     },
#     "Deferred Issues": [
#       {
#         "Code": "5206",
#         "Description": "RIGHT ELBOW, SECONDARY TO LEFT ELBOW",
#         "Left_or_Right_KW": "RIGHT"
#       },
#       {
#         "Code": "5271",
#         "Description": "RIGHT ANKLE CONDITION",
#         "Left_or_Right_KW": "RIGHT"
#       },
#       {
#         "Code": "5271",
#         "Description": "LEFT ANKLE CONDITION",
#         "Left_or_Right_KW": "LEFT"
#       },
#       {
#         "Code": "6512",
#         "Description": "SINUSITIS"
#       }
#     ],
#     "Decision": [
#       {
#         "DecisionName": "lumbosacral strain",
#         "DecisionEvalution": "40",
#         "EffDate": "November 29, 2022"
#       },
#       {
#         "DecisionName": "cervical strain",
#         "DecisionEvalution": "30",
#         "EffDate": "November 29, 2022"
#       },
#       {
#         "DecisionName": "headaches",
#         "DecisionEvalution": "30",
#         "EffDate": "November 29, 2022"
#       },
#       {
#         "DecisionName": "left forearm limited flexion",
#         "DecisionEvalution": "20",
#         "EffDate": "November 29, 2022"
#       },
#       {
#         "DecisionName": "left forearm limited rotation ",
#         "DecisionEvalution": "20",
#         "EffDate": "November 29, 2022"
#       },
#       {
#         "DecisionName": "tinnitus",
#         "DecisionEvalution": "10",
#         "EffDate": "November 29, 2022"
#       },
#       {
#         "DecisionName": "irritable bowel syndrome"
#       },
#       {
#         "DecisionName": "left arm radiculopathy"
#       },
#       {
#         "DecisionName": "left leg radiculopathy"
#       },
#       {
#         "DecisionName": "right arm radiculopathy"
#       },
#       {
#         "DecisionName": "right leg radiculopathy"
#       },
#       {
#         "DecisionName": "vertigo"
#       },
#       {
#         "DecisionName": "left ankle condition"
#       },
#       {
#         "DecisionName": "right ankle condition"
#       },
#       {
#         "DecisionName": "right elbow, secondary to left elbow"
#       },
#       {
#         "DecisionName": "sinusitis"
#       }
#     ]
#   }
# }

# %%
command = ["python3", "pdfParser.py", "--argument", pdf_file]
subprocess.run(command, cwd=current_dir)
pdf_file_copy_path = os.path.join(pdf_folder, pdf_file)
shutil.copy(os.path.join(current_dir, pdf_file), pdf_file_copy_path)
json_file = "file.json"
json_file_copy_path = os.path.join(pdf_folder, f"{os.path.splitext(pdf_file)[0]}.json")
shutil.move(os.path.join(current_dir, json_file), json_file_copy_path)
# Out:
# *******************************************
# *                  *                      *
# *      Welcome to the PDF Scraper!        *
# *                  *                      *
# *          Created by Workmovr            *
# *                  *                      *
# *******************************************
# RatingDecision -- 04-13-23 - 4HPGK2FV.pdf
# {
#   "Veteran Name": "None",
#   "VA File Number": "None",
#   "Social Security Number": "None",
#   "POA": "None",
#   "CLIENT_CASPIO_FK": "4HPGK2FV",
#   "HEADER_DATE": "04/10/2023",
#   "Service Dates": [
#     {
#       "EOD_Date": "11/18/1987",
#       "RAD_Date": "11/30/2007",
#       "Branch_Service": "Air Force",
#       "Discharge_Type": "Honorable"
#     }
#   ],
#   "Compensation": [
#     {
#       "Code": "9440",
#       "Description": "ADJUSTMENT DISORDER WITH DEPRESSED MOOD",
#       "PercentageDate": [
#         {
#           "percent": "50",
#           "date": "01/14/2020"
#         }
#       ]
#     },
#     {
#       "Code": "5276",
#       "Description": "BILATERAL PLANTAR FASCIITIS",
#       "PercentageDate": [
#         {
#           "percent": "30",
#           "date": "11/03/2020"
#         }
#       ]
#     },
#     {
#       "Code": "5201",
#       "Description": "LEFT SHOULDER TENDINITIS (PREVIOUSLY RATED UNDER DIAGNOSTIC CODE 5201 AND 5201-5019)",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "06/26/2015"
#         },
#         {
#           "percent": "20",
#           "date": "03/03/2017"
#         },
#         {
#           "percent": "20",
#           "date": "03/19/2019"
#         }
#       ],
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "6035-6066",
#       "Description": "KERATOCONUS",
#       "PercentageDate": [
#         {
#           "percent": "30",
#           "date": "12/01/2007"
#         },
#         {
#           "percent": "0",
#           "date": "11/01/2017"
#         },
#         {
#           "percent": "20",
#           "date": "01/25/2021"
#         }
#       ]
#     },
#     {
#       "Code": "5206",
#       "Description": "RIGHT LATERAL EPICONDYLITIS",
#       "PercentageDate": [
#         {
#           "percent": "20",
#           "date": "07/22/2022"
#         }
#       ],
#       "Left_or_Right_KW": "RIGHT"
#     },
#     {
#       "Code": "5024-5201",
#       "Description": "LEFT SHOULDER TENDINITIS",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "12/01/2007",
#           "End_Date": "06/26/2015"
#         },
#         {
#           "percent": "20",
#           "date": "12/29/2022"
#         }
#       ],
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "7899-7806",
#       "Description": "HERPES SIMPLEX TYPE II WITH ACNEFORM DERMATITIS, KERATOSIS PILARIS, AND FOLLICULITIS BARBAE (PREVIOUSLY EVALUATED SEPARATELY)",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "12/01/2007"
#         }
#       ]
#     },
#     {
#       "Code": "7399-7346",
#       "Description": "GASTROESOPHAGEAL REFLUX DISEASE WITH IRRITABLE BOWEL SYNDROME (IBS)",
#       "PercentageDate": [
#         {
#           "percent": "0",
#           "date": "12/01/2007"
#         },
#         {
#           "percent": "10",
#           "date": "07/21/2016"
#         }
#       ]
#     },
#     {
#       "Code": "6260",
#       "Description": "TINNITUS",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "08/03/2020"
#         }
#       ]
#     },
#     {
#       "Code": "6522",
#       "Description": "ALLERGIC RHINITIS",
#       "PercentageDate": [
#         {
#           "percent": "10",
#           "date": "01/20/2023"
#         }
#       ]
#     },
#     {
#       "Code": "7101",
#       "Description": "HYPERTENSION",
#       "PercentageDate": [
#         {
#           "percent": "0",
#           "date": "12/01/2007"
#         }
#       ]
#     },
#     {
#       "Code": "7522",
#       "Description": "ERECTILE DYSFUNCTION ASSOCIATED WITH HYPERTENSION",
#       "PercentageDate": [
#         {
#           "percent": "0",
#           "date": "07/22/2022"
#         }
#       ]
#     }
#   ],
#   "No Compensation": [
#     {
#       "Code": "5201",
#       "Description": "RIGHT SHOULDER STRAIN",
#       "Left_or_Right_KW": "RIGHT"
#     },
#     {
#       "Code": "5206",
#       "Description": "LEFT ELBOW CONDITION",
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "5237",
#       "Description": "NECK/UPPER BACK (CERVICAL SPINE)"
#     },
#     {
#       "Code": "5276",
#       "Description": "BILATERAL PES PLANUS"
#     },
#     {
#       "Code": "5299-5206",
#       "Description": "LEFT ELBOW CONDITION",
#       "Left_or_Right_KW": "LEFT"
#     },
#     {
#       "Code": "6313",
#       "Description": "VITAMIN D DEFICIENCY"
#     },
#     {
#       "Code": "6512",
#       "Description": "SINUSITIS (PARTICULATE EXPOSURE)"
#     },
#     {
#       "Code": "6847",
#       "Description": "SLEEP APNEA SYNDROMES"
#     },
#     {
#       "Code": "7599-7502",
#       "Description": "KIDNEY DYSFUNCTION (SECONDARY TO HTN)"
#     },
#     {
#       "Code": "7800",
#       "Description": "SURGICAL SCAR ON NECK"
#     },
#     {
#       "Code": "7806",
#       "Description": "ECZEMA"
#     },
#     {
#       "Code": "7820",
#       "Description": "PITYRIASIS ROSEA"
#     },
#     {
#       "Code": "7825",
#       "Description": "URTICARIA"
#     },
#     {
#       "Code": "7903",
#       "Description": "HYPOTHYROIDISM STATUS POST PARTIAL THYROIDECTOMY FOR TREATMENT OF HYPERTHYROIDISM (GRAVE'S DISEASE)"
#     },
#     {
#       "Code": "8100",
#       "Description": "HEADACHES"
#     },
#     {
#       "Code": "8515",
#       "Description": "RIGHT CARPAL TUNNEL SYNDROME",
#       "Left_or_Right_KW": "RIGHT"
#     },
#     {
#       "Code": "8515",
#       "Description": "LEFT CARPAL TUNNEL SYNDROME",
#       "Left_or_Right_KW": "LEFT"
#     }
#   ],
#   "Deferred Issues": [],
#   "Decision": [
#     {
#       "DecisionName": "right lateral epicondylitis ",
#       "DecisionEvalution": "20",
#       "EffDate": "July 22, 2022"
#     },
#     {
#       "DecisionName": "erectile dysfunction",
#       "DecisionEvalution": "0",
#       "EffDate": "July 22, 2022"
#     },
#     {
#       "EffDate": "July 22, 2022"
#     },
#     {
#       "DecisionName": "left elbow condition"
#     }
#   ]
# }
# 'RatingDecision -- 04-13-23 - 4HPGK2FV/RatingDecision -- 04-13-23 - 4HPGK2FV.json'
